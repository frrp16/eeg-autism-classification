# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import preprocessing, model_selection
import csv
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import time
import json
import random

# %% [markdown]
# ### Data Preparation

# %%
def get_dataset(directory, lag, excluded_name=[]):
    data = pd.DataFrame(columns=['data', 'label'])
    for foldername in os.listdir(directory):        
        folder = os.path.join(directory, foldername)
        # print(folder)
        if str(lag) in folder:
            # print(os.listdir(folder))
            for name in os.listdir(folder):
                if name in excluded_name:
                    # print(name)
                    continue
                filename = os.path.join(folder, name)
                # print(filename)
                for files in os.listdir(filename):
                    rel_path = os.path.join(filename, files)
                    # print(rel_path)
                    temp_label = folder
                    if "autism" in temp_label:
                        label = 'autism'
                    else:
                        label = 'normal'

                    temp_data = pd.DataFrame(columns=['data', 'label'], index=[0])

                    rwb = np.load(rel_path)
                    rwb.astype(np.float64).reshape(-1,1)
                                    
                    temp_data.loc[0, "data"] = rwb
                    temp_data['label'] = label
                    data = pd.concat([data, temp_data], ignore_index=True)
    label_map = {"autism": 1, "normal": 0}
    data['label_map'] = data['label'].map(label_map)      
    return data

# %%
def remove_missing_value(data):
    series_list = np.vstack(data["data"].values)
    labels_list = data["label_map"].values    
    missing_indices = np.where(np.isnan(series_list).any(axis=1))[0]

    clean_data = data.drop(index=data.index[missing_indices])
    return clean_data

# %%
# temp_data = pd.DataFrame(columns=['data', 'label'], index=[0])
# rwb = np.load("datasets/features/rwb/segment_1 seconds/autism_256/bader/Bader_segment_100.csv_bispectrum.npy")
# rwb.astype(np.float64).reshape(-1,1)
# temp_data.loc[0, "data"] = rwb
# temp_data['label'] = "autism"

# %%
def save_dataset(data, des_path):
    if not os.path.exists(des_path):
        os.makedirs(des_path)
    data.save(des_path)

# %%
def get_train_test(data, train_split: float):
    train_x, test_x, train_y, test_y = model_selection.train_test_split(
        data['data'],
        data[['label', 'label_map']],
        train_size=train_split,
        stratify=data['label_map']
    )

    train_df = pd.DataFrame(columns=['data', 'label', 'label_map'])
    test_df = pd.DataFrame(columns=['data', 'label', 'label_map'])

    train_df["data"] = train_x
    train_df[['label', 'label_map']] = train_y

    test_df["data"] = test_x
    test_df[['label', 'label_map']] = test_y

    return train_df, test_df

# %%
def get_batch(data):
    # loading extracted feature & label
    # x = get_dataset(path, lag, excluded_name)

    # scaler = preprocessing.MinMaxScaler()

    series_list = np.vstack(data["data"].values)

    # series_list = series_list.reshape(-1, 366, 1)

    labels_list = data["label_map"].values
        
    # y = keras.utils.to_categorical(y[0])
    dataset = tf.data.Dataset.from_tensor_slices((series_list,labels_list))
    dataset = dataset.shuffle(len(labels_list))

    # train_size = int(train_split * len(labels_list))  
    # test_size = len(labels_list) - train_size  

    # train_dataset = dataset.take(train_size)
    # test_dataset = dataset.skip(train_size)

    BATCH_SIZE = 32

    dataset = dataset.batch(BATCH_SIZE)

    return dataset

# %%
# train_x, test_x, train_y, test_y = model_selection.train_test_split(
#         data['data'],
#         data[['label', 'label_map']],
#         train_size=0.8,
#         stratify=data['label_map']
#     )

# train_df = pd.DataFrame(columns=['data', 'label', 'label_map'])
# test_df = pd.DataFrame(columns=['data', 'label', 'label_map'])

# train_df["data"] = train_x
# train_df[['label', 'label_map']] = train_y

# test_df["data"] = test_x
# test_df[['label', 'label_map']] = test_y

# %%
def relative_transform(data):    
    series_list = np.vstack(data["data"].values)
    labels_list = data["label_map"].values  

    relative_energy = np.zeros([series_list.shape[0], series_list.shape[1]])
    for i, series in enumerate(series_list):
        total_energy = np.sum(series)
        relative_energy[i] = [(s / total_energy) * 100 for s in series]
    relative_energy_list = [arr for arr in relative_energy]
    data["data"] = relative_energy_list
    return data

# %%
# excluded = ["zyad"]
# data = get_dataset(data_dir, 256, excluded_name=excluded)

# %%
# temp = data["data"].values
# series_list = np.vstack(temp)
# series_list = series_list.reshape(-1, 96, 1)

# %%
SEGMENT_TIME = 1

data_dir = f"datasets/features/rwb_6_lvl/segment_{SEGMENT_TIME} seconds"

train_dir = f"datasets/tf_batch/rwb_6_lvl/segment_{SEGMENT_TIME} seconds/train"
test_dir = f"datasets/tf_batch/rwb_6_lvl/segment_{SEGMENT_TIME} seconds/test"

# %%
# excluded = ["zyad"]
# data = get_dataset(data_dir, 256, excluded)

# %%
# data.shape[0]

# %%
# series_list = np.vstack(data["data"].values)
# labels_list = data["label_map"].values    
# missing_indices = np.where(np.isnan(series_list).any(axis=1))[0]

# clean_data = data.drop(index=data.index[missing_indices])

# %%
# clean_data.shape[0]

# %%
excluded = ["zyad"]
train_split = 0.8
LAG = [256]

for lag in LAG:
    data = get_dataset(data_dir, lag, excluded)
    print(data.shape)
    # data = relative_transform(data)
    data = remove_missing_value(data)
    print(data.shape)
    train_data, test_data = get_train_test(data, train_split)
    print("train: ", train_data.shape)
    print("test: ", test_data.shape)
    train_batch = get_batch(train_data)
    test_batch = get_batch(test_data)
    tf.data.Dataset.save(train_batch, f"{train_dir}_{lag}")
    tf.data.Dataset.save(test_batch, f"{test_dir}_{lag}")
# Out:
# (15434, 3)
# (14618, 3)
# train:  (11694, 3)
# test:  (2924, 3)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Load the CSV file into a DataFrame
signal = np.load(f"datasets/features/rwb_6_lvl/segment_{SEGMENT_TIME} seconds/normal_{LAG[0]}/amer/Amer_segment_1.csv_rwb.npy")

# Extract the signal values from the DataFrame
print(signal.shape)
# Create a time axis for the signal
t = range(len(signal))

fig, ax = plt.subplots(figsize=(10, 5))
# Plot the signal
ax.plot(t, signal)
ax.set_xlabel('Time (samples)')
ax.set_ylabel('Signal amplitude')
ax.set_title('Signal plot')
plt.show()
# Out:
# (96,)

# %% [markdown]
# ### Model Definition

# %%
input_size = 42

def create_model():
    model = keras.models.Sequential()

    model.add(layers.Input(shape=(input_size,)))
    model.add(layers.Reshape((input_size, 1)))

    model.add(layers.Flatten())

    model.add(layers.Dense(512, activation="relu"))

    model.add(layers.Dropout(0.5))

    model.add(layers.Dense(256, activation="relu"))

    model.add(layers.Dropout(0.5))

    model.add(layers.Dense(1, activation="sigmoid"))

    return model

# %% [markdown]
# ### Define Callbacks

# %%
def myCallbacks(log_dir):
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
    early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='acc',
    patience=50,
    mode='max')
    model_path = os.path.join(log_dir,'best_model.h5')
    mc = tf.keras.callbacks.ModelCheckpoint(model_path, monitor='val_acc', mode='max', verbose=1, save_best_only=True)
    return [tensorboard_callback, early_stopping, mc]

# %% [markdown]
# ### Main Program

# %%
lags = [256]
# folds = ['train_1', 'test_1', 'epoch_1', 'train_2', 'test_2', 'epoch_2']
time_measured = ['Wall_Time_1', 'CPU_Time_1', 'Wall_Time_2', 'CPU_Time_2']
epochs = 1000
log_dirs = [f"train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam"]

# %%
for log_dir in log_dirs:
    recap = pd.DataFrame(index=lags, columns=range(1, 6))
    training_time = pd.DataFrame(index=lags, columns=[f'CPU_Time_{i}' for i in range(1, 6)] + [f'Wall_Time_{i}' for i in range(1, 6)])

    for lag in lags:
        train_temp_dir = train_dir + '_' + str(lag)
        train = tf.data.Dataset.load(train_temp_dir)
        flattened_train = train.unbatch()

        train_data = list(flattened_train.as_numpy_iterator())
        train_size = len(list(train_data))

        kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=42)

        for fold, (train_index, val_index) in enumerate(kf.split(train_data), 1):
            train_fold_data = ([train_data[i][0] for i in train_index], [train_data[i][1] for i in train_index])
            val_fold_data = ([train_data[i][0] for i in val_index], [train_data[i][1] for i in val_index])

            train_fold = tf.data.Dataset.from_tensor_slices(train_fold_data).batch(32)
            val_fold = tf.data.Dataset.from_tensor_slices(val_fold_data).batch(32)

            log_path = os.path.join(log_dir, str(fold), str(lag))

            model = create_model()
            model.summary()

            model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['acc'])

            cpu_start = time.process_time()
            wt_start = time.time()

            history = model.fit(train_fold, epochs=epochs, validation_data=val_fold, callbacks=myCallbacks(log_path))

            wt_end = time.time()
            cpu_end = time.process_time()
            wall_time = wt_end - wt_start
            cpu_time = cpu_end - cpu_start

            training_time.loc[lag, f'CPU_Time_{fold}'] = cpu_time
            training_time.loc[lag, f'Wall_Time_{fold}'] = wall_time

            recap.loc[lag, fold] = history.history['acc'][-1]


    # Evaluate on the test dataset after cross-validation
    test_temp_dir = test_dir + '_' + str(lag)
    test_ds = tf.data.Dataset.load(test_temp_dir)
    results = model.evaluate(test_ds, callbacks=myCallbacks(log_path))

    recap[f'test_{lag}'] = results[1]

    log_recap_dir = os.path.join(log_dir, 'Recap')
    if not os.path.exists(log_recap_dir):
        os.makedirs(log_recap_dir)

    recap.to_csv(os.path.join(log_recap_dir, 'recap.csv'))
    training_time.to_csv(os.path.join(log_recap_dir, 'Training_time.csv'))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 42, 1)             0
#
#  flatten (Flatten)           (None, 42)                0
#
#  dense (Dense)               (None, 512)               22016
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 153,601
# Trainable params: 153,601
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 291/297 [============================>.] - ETA: 0s - loss: 1.4793 - acc: 0.6230
# Epoch 1: val_acc improved from -inf to 0.69646, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 3s 6ms/step - loss: 1.4649 - acc: 0.6237 - val_loss: 0.6418 - val_acc: 0.6965
# Epoch 2/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.6335 - acc: 0.6768
# Epoch 2: val_acc did not improve from 0.69646
# 297/297 [==============================] - 2s 6ms/step - loss: 0.6346 - acc: 0.6763 - val_loss: 0.6186 - val_acc: 0.6948
# Epoch 3/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.6101 - acc: 0.6946
# Epoch 3: val_acc improved from 0.69646 to 0.70784, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 4ms/step - loss: 0.6101 - acc: 0.6949 - val_loss: 0.5945 - val_acc: 0.7078
# Epoch 4/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.5973 - acc: 0.7033
# Epoch 4: val_acc improved from 0.70784 to 0.71037, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5978 - acc: 0.7028 - val_loss: 0.5904 - val_acc: 0.7104
# Epoch 5/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.5863 - acc: 0.7072
# Epoch 5: val_acc improved from 0.71037 to 0.71627, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 4ms/step - loss: 0.5865 - acc: 0.7072 - val_loss: 0.5849 - val_acc: 0.7163
# Epoch 6/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.5838 - acc: 0.7112
# Epoch 6: val_acc improved from 0.71627 to 0.71712, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 4ms/step - loss: 0.5848 - acc: 0.7105 - val_loss: 0.5751 - val_acc: 0.7171
# Epoch 7/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.5790 - acc: 0.7180
# Epoch 7: val_acc improved from 0.71712 to 0.71922, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5799 - acc: 0.7174 - val_loss: 0.5739 - val_acc: 0.7192
# Epoch 8/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.5790 - acc: 0.7091
# Epoch 8: val_acc did not improve from 0.71922
# 297/297 [==============================] - 1s 4ms/step - loss: 0.5799 - acc: 0.7082 - val_loss: 0.5744 - val_acc: 0.7159
# Epoch 9/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.5726 - acc: 0.7148
# Epoch 9: val_acc improved from 0.71922 to 0.72133, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 4ms/step - loss: 0.5735 - acc: 0.7142 - val_loss: 0.5737 - val_acc: 0.7213
# Epoch 10/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.5658 - acc: 0.7196
# Epoch 10: val_acc improved from 0.72133 to 0.72218, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 4ms/step - loss: 0.5667 - acc: 0.7190 - val_loss: 0.5731 - val_acc: 0.7222
# Epoch 11/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.5649 - acc: 0.7217
# Epoch 11: val_acc improved from 0.72218 to 0.72470, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5660 - acc: 0.7213 - val_loss: 0.5672 - val_acc: 0.7247
# Epoch 12/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.5619 - acc: 0.7179
# Epoch 12: val_acc did not improve from 0.72470
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5619 - acc: 0.7179 - val_loss: 0.5619 - val_acc: 0.7247
# Epoch 13/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.5621 - acc: 0.7228
# Epoch 13: val_acc improved from 0.72470 to 0.72850, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5624 - acc: 0.7226 - val_loss: 0.5574 - val_acc: 0.7285
# Epoch 14/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.5567 - acc: 0.7276
# Epoch 14: val_acc did not improve from 0.72850
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5568 - acc: 0.7275 - val_loss: 0.5577 - val_acc: 0.7226
# Epoch 15/1000
# 286/297 [===========================>..] - ETA: 0s - loss: 0.5538 - acc: 0.7260
# Epoch 15: val_acc did not improve from 0.72850
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5547 - acc: 0.7244 - val_loss: 0.5528 - val_acc: 0.7268
# Epoch 16/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.5499 - acc: 0.7275
# Epoch 16: val_acc did not improve from 0.72850
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5499 - acc: 0.7275 - val_loss: 0.5655 - val_acc: 0.7230
# Epoch 17/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.5531 - acc: 0.7269
# Epoch 17: val_acc did not improve from 0.72850
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5535 - acc: 0.7263 - val_loss: 0.5499 - val_acc: 0.7272
# Epoch 18/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.5475 - acc: 0.7265
# Epoch 18: val_acc improved from 0.72850 to 0.73103, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5475 - acc: 0.7265 - val_loss: 0.5497 - val_acc: 0.7310
# Epoch 19/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.5473 - acc: 0.7259
# Epoch 19: val_acc did not improve from 0.73103
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5480 - acc: 0.7251 - val_loss: 0.5428 - val_acc: 0.7298
# Epoch 20/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.5415 - acc: 0.7325
# Epoch 20: val_acc did not improve from 0.73103
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5424 - acc: 0.7317 - val_loss: 0.5444 - val_acc: 0.7306
# Epoch 21/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.5407 - acc: 0.7333
# Epoch 21: val_acc improved from 0.73103 to 0.73145, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 4ms/step - loss: 0.5414 - acc: 0.7331 - val_loss: 0.5576 - val_acc: 0.7315
# Epoch 22/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.5386 - acc: 0.7342
# Epoch 22: val_acc improved from 0.73145 to 0.73524, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5393 - acc: 0.7340 - val_loss: 0.5395 - val_acc: 0.7352
# Epoch 23/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.5351 - acc: 0.7360
# Epoch 23: val_acc did not improve from 0.73524
# 297/297 [==============================] - 1s 4ms/step - loss: 0.5359 - acc: 0.7352 - val_loss: 0.5458 - val_acc: 0.7319
# Epoch 24/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.5324 - acc: 0.7381
# Epoch 24: val_acc did not improve from 0.73524
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5330 - acc: 0.7378 - val_loss: 0.5490 - val_acc: 0.7348
# Epoch 25/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.5343 - acc: 0.7381
# Epoch 25: val_acc did not improve from 0.73524
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5349 - acc: 0.7366 - val_loss: 0.5391 - val_acc: 0.7323
# Epoch 26/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.5321 - acc: 0.7350
# Epoch 26: val_acc did not improve from 0.73524
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5324 - acc: 0.7347 - val_loss: 0.5394 - val_acc: 0.7348
# Epoch 27/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.5328 - acc: 0.7354
# Epoch 27: val_acc improved from 0.73524 to 0.73820, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5339 - acc: 0.7352 - val_loss: 0.5376 - val_acc: 0.7382
# Epoch 28/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.5313 - acc: 0.7394
# Epoch 28: val_acc improved from 0.73820 to 0.74831, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5319 - acc: 0.7388 - val_loss: 0.5293 - val_acc: 0.7483
# Epoch 29/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.5232 - acc: 0.7433
# Epoch 29: val_acc did not improve from 0.74831
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5246 - acc: 0.7425 - val_loss: 0.5326 - val_acc: 0.7441
# Epoch 30/1000
# 285/297 [===========================>..] - ETA: 0s - loss: 0.5235 - acc: 0.7402
# Epoch 30: val_acc improved from 0.74831 to 0.74916, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5251 - acc: 0.7375 - val_loss: 0.5326 - val_acc: 0.7492
# Epoch 31/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.5228 - acc: 0.7414
# Epoch 31: val_acc improved from 0.74916 to 0.75084, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5247 - acc: 0.7402 - val_loss: 0.5280 - val_acc: 0.7508
# Epoch 32/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.5221 - acc: 0.7417
# Epoch 32: val_acc did not improve from 0.75084
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5228 - acc: 0.7408 - val_loss: 0.5257 - val_acc: 0.7449
# Epoch 33/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.5225 - acc: 0.7425
# Epoch 33: val_acc did not improve from 0.75084
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5237 - acc: 0.7414 - val_loss: 0.5279 - val_acc: 0.7462
# Epoch 34/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.5191 - acc: 0.7416
# Epoch 34: val_acc improved from 0.75084 to 0.75169, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5201 - acc: 0.7411 - val_loss: 0.5381 - val_acc: 0.7517
# Epoch 35/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.5214 - acc: 0.7418
# Epoch 35: val_acc did not improve from 0.75169
# 297/297 [==============================] - 2s 7ms/step - loss: 0.5219 - acc: 0.7411 - val_loss: 0.5319 - val_acc: 0.7504
# Epoch 36/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.5159 - acc: 0.7459
# Epoch 36: val_acc did not improve from 0.75169
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5162 - acc: 0.7447 - val_loss: 0.5318 - val_acc: 0.7508
# Epoch 37/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.5110 - acc: 0.7458
# Epoch 37: val_acc did not improve from 0.75169
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5112 - acc: 0.7457 - val_loss: 0.5375 - val_acc: 0.7416
# Epoch 38/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.5155 - acc: 0.7482
# Epoch 38: val_acc did not improve from 0.75169
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5160 - acc: 0.7480 - val_loss: 0.5333 - val_acc: 0.7517
# Epoch 39/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.5054 - acc: 0.7475
# Epoch 39: val_acc did not improve from 0.75169
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5072 - acc: 0.7461 - val_loss: 0.5314 - val_acc: 0.7500
# Epoch 40/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.5069 - acc: 0.7539
# Epoch 40: val_acc did not improve from 0.75169
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5086 - acc: 0.7526 - val_loss: 0.5281 - val_acc: 0.7437
# Epoch 41/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.5081 - acc: 0.7519
# Epoch 41: val_acc improved from 0.75169 to 0.75379, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5090 - acc: 0.7509 - val_loss: 0.5229 - val_acc: 0.7538
# Epoch 42/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.5113 - acc: 0.7500
# Epoch 42: val_acc did not improve from 0.75379
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5120 - acc: 0.7498 - val_loss: 0.5281 - val_acc: 0.7496
# Epoch 43/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.5107 - acc: 0.7486
# Epoch 43: val_acc did not improve from 0.75379
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5107 - acc: 0.7486 - val_loss: 0.5271 - val_acc: 0.7530
# Epoch 44/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.5076 - acc: 0.7520
# Epoch 44: val_acc did not improve from 0.75379
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5082 - acc: 0.7518 - val_loss: 0.5225 - val_acc: 0.7513
# Epoch 45/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.5054 - acc: 0.7529
# Epoch 45: val_acc did not improve from 0.75379
# 297/297 [==============================] - 2s 5ms/step - loss: 0.5069 - acc: 0.7516 - val_loss: 0.5222 - val_acc: 0.7483
# Epoch 46/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.5070 - acc: 0.7509
# Epoch 46: val_acc did not improve from 0.75379
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5078 - acc: 0.7506 - val_loss: 0.5250 - val_acc: 0.7470
# Epoch 47/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.5096 - acc: 0.7525
# Epoch 47: val_acc did not improve from 0.75379
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5103 - acc: 0.7516 - val_loss: 0.5273 - val_acc: 0.7458
# Epoch 48/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.5054 - acc: 0.7539
# Epoch 48: val_acc did not improve from 0.75379
# 297/297 [==============================] - 1s 5ms/step - loss: 0.5065 - acc: 0.7530 - val_loss: 0.5261 - val_acc: 0.7517
# Epoch 49/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.5004 - acc: 0.7550
# Epoch 49: val_acc did not improve from 0.75379
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5024 - acc: 0.7543 - val_loss: 0.5194 - val_acc: 0.7525
# Epoch 50/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.5039 - acc: 0.7534
# Epoch 50: val_acc did not improve from 0.75379
# 297/297 [==============================] - 2s 7ms/step - loss: 0.5049 - acc: 0.7528 - val_loss: 0.5193 - val_acc: 0.7530
# Epoch 51/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4989 - acc: 0.7567
# Epoch 51: val_acc improved from 0.75379 to 0.75759, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4990 - acc: 0.7567 - val_loss: 0.5264 - val_acc: 0.7576
# Epoch 52/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.5046 - acc: 0.7519
# Epoch 52: val_acc did not improve from 0.75759
# 297/297 [==============================] - 2s 6ms/step - loss: 0.5046 - acc: 0.7519 - val_loss: 0.5199 - val_acc: 0.7504
# Epoch 53/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.5017 - acc: 0.7562
# Epoch 53: val_acc did not improve from 0.75759
# 297/297 [==============================] - 3s 9ms/step - loss: 0.5024 - acc: 0.7557 - val_loss: 0.5218 - val_acc: 0.7479
# Epoch 54/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.4984 - acc: 0.7575
# Epoch 54: val_acc did not improve from 0.75759
# 297/297 [==============================] - 2s 7ms/step - loss: 0.5000 - acc: 0.7566 - val_loss: 0.5246 - val_acc: 0.7466
# Epoch 55/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.4993 - acc: 0.7553
# Epoch 55: val_acc did not improve from 0.75759
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4995 - acc: 0.7553 - val_loss: 0.5134 - val_acc: 0.7521
# Epoch 56/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.5022 - acc: 0.7573
# Epoch 56: val_acc did not improve from 0.75759
# 297/297 [==============================] - 2s 7ms/step - loss: 0.5023 - acc: 0.7573 - val_loss: 0.5203 - val_acc: 0.7517
# Epoch 57/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4980 - acc: 0.7611
# Epoch 57: val_acc did not improve from 0.75759
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4983 - acc: 0.7604 - val_loss: 0.5195 - val_acc: 0.7530
# Epoch 58/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4912 - acc: 0.7591
# Epoch 58: val_acc did not improve from 0.75759
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4923 - acc: 0.7578 - val_loss: 0.5202 - val_acc: 0.7517
# Epoch 59/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.4936 - acc: 0.7636
# Epoch 59: val_acc did not improve from 0.75759
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4943 - acc: 0.7629 - val_loss: 0.5186 - val_acc: 0.7475
# Epoch 60/1000
# 287/297 [===========================>..] - ETA: 0s - loss: 0.4915 - acc: 0.7579
# Epoch 60: val_acc did not improve from 0.75759
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4915 - acc: 0.7580 - val_loss: 0.5131 - val_acc: 0.7542
# Epoch 61/1000
# 286/297 [===========================>..] - ETA: 0s - loss: 0.4950 - acc: 0.7623
# Epoch 61: val_acc did not improve from 0.75759
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4968 - acc: 0.7609 - val_loss: 0.5159 - val_acc: 0.7487
# Epoch 62/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4950 - acc: 0.7590
# Epoch 62: val_acc did not improve from 0.75759
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4960 - acc: 0.7579 - val_loss: 0.5233 - val_acc: 0.7538
# Epoch 63/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.4882 - acc: 0.7615
# Epoch 63: val_acc did not improve from 0.75759
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4887 - acc: 0.7610 - val_loss: 0.5207 - val_acc: 0.7530
# Epoch 64/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4915 - acc: 0.7585
# Epoch 64: val_acc did not improve from 0.75759
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4922 - acc: 0.7581 - val_loss: 0.5217 - val_acc: 0.7525
# Epoch 65/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4883 - acc: 0.7574
# Epoch 65: val_acc did not improve from 0.75759
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4888 - acc: 0.7574 - val_loss: 0.5188 - val_acc: 0.7576
# Epoch 66/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.4859 - acc: 0.7613
# Epoch 66: val_acc did not improve from 0.75759
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4870 - acc: 0.7604 - val_loss: 0.5179 - val_acc: 0.7534
# Epoch 67/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4896 - acc: 0.7622
# Epoch 67: val_acc improved from 0.75759 to 0.76012, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4909 - acc: 0.7614 - val_loss: 0.5134 - val_acc: 0.7601
# Epoch 68/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4843 - acc: 0.7646
# Epoch 68: val_acc did not improve from 0.76012
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4853 - acc: 0.7641 - val_loss: 0.5240 - val_acc: 0.7534
# Epoch 69/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.4886 - acc: 0.7620
# Epoch 69: val_acc did not improve from 0.76012
# 297/297 [==============================] - 1s 4ms/step - loss: 0.4893 - acc: 0.7612 - val_loss: 0.5146 - val_acc: 0.7496
# Epoch 70/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4858 - acc: 0.7649
# Epoch 70: val_acc improved from 0.76012 to 0.76138, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4865 - acc: 0.7648 - val_loss: 0.5090 - val_acc: 0.7614
# Epoch 71/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.4872 - acc: 0.7624
# Epoch 71: val_acc did not improve from 0.76138
# 297/297 [==============================] - 2s 8ms/step - loss: 0.4876 - acc: 0.7622 - val_loss: 0.5115 - val_acc: 0.7563
# Epoch 72/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.4804 - acc: 0.7660
# Epoch 72: val_acc did not improve from 0.76138
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4810 - acc: 0.7655 - val_loss: 0.5150 - val_acc: 0.7555
# Epoch 73/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4820 - acc: 0.7691
# Epoch 73: val_acc did not improve from 0.76138
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4829 - acc: 0.7686 - val_loss: 0.5173 - val_acc: 0.7584
# Epoch 74/1000
# 287/297 [===========================>..] - ETA: 0s - loss: 0.4864 - acc: 0.7658
# Epoch 74: val_acc did not improve from 0.76138
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4865 - acc: 0.7654 - val_loss: 0.5173 - val_acc: 0.7538
# Epoch 75/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4782 - acc: 0.7672
# Epoch 75: val_acc improved from 0.76138 to 0.76349, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4788 - acc: 0.7670 - val_loss: 0.5107 - val_acc: 0.7635
# Epoch 76/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4841 - acc: 0.7679
# Epoch 76: val_acc improved from 0.76349 to 0.76602, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 7ms/step - loss: 0.4853 - acc: 0.7672 - val_loss: 0.5092 - val_acc: 0.7660
# Epoch 77/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4804 - acc: 0.7679
# Epoch 77: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4811 - acc: 0.7667 - val_loss: 0.5079 - val_acc: 0.7639
# Epoch 78/1000
# 287/297 [===========================>..] - ETA: 0s - loss: 0.4845 - acc: 0.7651
# Epoch 78: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4865 - acc: 0.7638 - val_loss: 0.5104 - val_acc: 0.7593
# Epoch 79/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4850 - acc: 0.7644
# Epoch 79: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4855 - acc: 0.7636 - val_loss: 0.5114 - val_acc: 0.7538
# Epoch 80/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4790 - acc: 0.7655
# Epoch 80: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4800 - acc: 0.7648 - val_loss: 0.5127 - val_acc: 0.7559
# Epoch 81/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4766 - acc: 0.7677
# Epoch 81: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4778 - acc: 0.7661 - val_loss: 0.5119 - val_acc: 0.7635
# Epoch 82/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4764 - acc: 0.7698
# Epoch 82: val_acc did not improve from 0.76602
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4779 - acc: 0.7689 - val_loss: 0.5140 - val_acc: 0.7614
# Epoch 83/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.4799 - acc: 0.7655
# Epoch 83: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4812 - acc: 0.7648 - val_loss: 0.5188 - val_acc: 0.7521
# Epoch 84/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4753 - acc: 0.7696
# Epoch 84: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4752 - acc: 0.7687 - val_loss: 0.5133 - val_acc: 0.7626
# Epoch 85/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.4731 - acc: 0.7714
# Epoch 85: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4741 - acc: 0.7711 - val_loss: 0.5072 - val_acc: 0.7580
# Epoch 86/1000
# 287/297 [===========================>..] - ETA: 0s - loss: 0.4716 - acc: 0.7720
# Epoch 86: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4728 - acc: 0.7701 - val_loss: 0.5228 - val_acc: 0.7534
# Epoch 87/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.4717 - acc: 0.7688
# Epoch 87: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4731 - acc: 0.7679 - val_loss: 0.5266 - val_acc: 0.7525
# Epoch 88/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.4742 - acc: 0.7711
# Epoch 88: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4743 - acc: 0.7718 - val_loss: 0.5196 - val_acc: 0.7559
# Epoch 89/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.4747 - acc: 0.7711
# Epoch 89: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4760 - acc: 0.7697 - val_loss: 0.5192 - val_acc: 0.7601
# Epoch 90/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.4730 - acc: 0.7699
# Epoch 90: val_acc did not improve from 0.76602
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4745 - acc: 0.7692 - val_loss: 0.5261 - val_acc: 0.7639
# Epoch 91/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.4778 - acc: 0.7705
# Epoch 91: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4778 - acc: 0.7705 - val_loss: 0.5207 - val_acc: 0.7580
# Epoch 92/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.4708 - acc: 0.7708
# Epoch 92: val_acc did not improve from 0.76602
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4709 - acc: 0.7707 - val_loss: 0.5287 - val_acc: 0.7610
# Epoch 93/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.4736 - acc: 0.7707
# Epoch 93: val_acc did not improve from 0.76602
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4736 - acc: 0.7707 - val_loss: 0.5180 - val_acc: 0.7525
# Epoch 94/1000
# 287/297 [===========================>..] - ETA: 0s - loss: 0.4721 - acc: 0.7746
# Epoch 94: val_acc did not improve from 0.76602
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4736 - acc: 0.7736 - val_loss: 0.5110 - val_acc: 0.7622
# Epoch 95/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.4724 - acc: 0.7704
# Epoch 95: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4730 - acc: 0.7700 - val_loss: 0.5255 - val_acc: 0.7508
# Epoch 96/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.4695 - acc: 0.7733
# Epoch 96: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4695 - acc: 0.7733 - val_loss: 0.5217 - val_acc: 0.7530
# Epoch 97/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.4699 - acc: 0.7702
# Epoch 97: val_acc did not improve from 0.76602
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4699 - acc: 0.7702 - val_loss: 0.5243 - val_acc: 0.7542
# Epoch 98/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.4699 - acc: 0.7753
# Epoch 98: val_acc improved from 0.76602 to 0.76728, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4710 - acc: 0.7748 - val_loss: 0.5253 - val_acc: 0.7673
# Epoch 99/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4720 - acc: 0.7688
# Epoch 99: val_acc did not improve from 0.76728
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4720 - acc: 0.7688 - val_loss: 0.5253 - val_acc: 0.7589
# Epoch 100/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4672 - acc: 0.7760
# Epoch 100: val_acc did not improve from 0.76728
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4671 - acc: 0.7761 - val_loss: 0.5385 - val_acc: 0.7597
# Epoch 101/1000
# 286/297 [===========================>..] - ETA: 0s - loss: 0.4678 - acc: 0.7760
# Epoch 101: val_acc did not improve from 0.76728
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4688 - acc: 0.7754 - val_loss: 0.5257 - val_acc: 0.7576
# Epoch 102/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4678 - acc: 0.7741
# Epoch 102: val_acc did not improve from 0.76728
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4684 - acc: 0.7734 - val_loss: 0.5312 - val_acc: 0.7530
# Epoch 103/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.4647 - acc: 0.7739
# Epoch 103: val_acc did not improve from 0.76728
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4661 - acc: 0.7731 - val_loss: 0.5245 - val_acc: 0.7572
# Epoch 104/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4577 - acc: 0.7790
# Epoch 104: val_acc did not improve from 0.76728
# 297/297 [==============================] - 1s 4ms/step - loss: 0.4581 - acc: 0.7789 - val_loss: 0.5251 - val_acc: 0.7614
# Epoch 105/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.4647 - acc: 0.7751
# Epoch 105: val_acc did not improve from 0.76728
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4656 - acc: 0.7746 - val_loss: 0.5305 - val_acc: 0.7580
# Epoch 106/1000
# 287/297 [===========================>..] - ETA: 0s - loss: 0.4656 - acc: 0.7760
# Epoch 106: val_acc did not improve from 0.76728
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4664 - acc: 0.7759 - val_loss: 0.5310 - val_acc: 0.7555
# Epoch 107/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.4655 - acc: 0.7733
# Epoch 107: val_acc did not improve from 0.76728
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4655 - acc: 0.7735 - val_loss: 0.5264 - val_acc: 0.7597
# Epoch 108/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.4628 - acc: 0.7724
# Epoch 108: val_acc did not improve from 0.76728
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4642 - acc: 0.7714 - val_loss: 0.5240 - val_acc: 0.7601
# Epoch 109/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4580 - acc: 0.7770
# Epoch 109: val_acc did not improve from 0.76728
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4579 - acc: 0.7771 - val_loss: 0.5239 - val_acc: 0.7542
# Epoch 110/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4603 - acc: 0.7787
# Epoch 110: val_acc did not improve from 0.76728
# 297/297 [==============================] - 1s 4ms/step - loss: 0.4605 - acc: 0.7784 - val_loss: 0.5184 - val_acc: 0.7614
# Epoch 111/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.4576 - acc: 0.7788
# Epoch 111: val_acc did not improve from 0.76728
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4595 - acc: 0.7769 - val_loss: 0.5212 - val_acc: 0.7563
# Epoch 112/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.4595 - acc: 0.7734
# Epoch 112: val_acc improved from 0.76728 to 0.76939, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4595 - acc: 0.7734 - val_loss: 0.5157 - val_acc: 0.7694
# Epoch 113/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.4580 - acc: 0.7743
# Epoch 113: val_acc did not improve from 0.76939
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4587 - acc: 0.7734 - val_loss: 0.5148 - val_acc: 0.7576
# Epoch 114/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4552 - acc: 0.7775
# Epoch 114: val_acc improved from 0.76939 to 0.76981, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4558 - acc: 0.7771 - val_loss: 0.5151 - val_acc: 0.7698
# Epoch 115/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4650 - acc: 0.7767
# Epoch 115: val_acc did not improve from 0.76981
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4649 - acc: 0.7769 - val_loss: 0.5113 - val_acc: 0.7610
# Epoch 116/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4551 - acc: 0.7828
# Epoch 116: val_acc did not improve from 0.76981
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4564 - acc: 0.7823 - val_loss: 0.5301 - val_acc: 0.7576
# Epoch 117/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.4539 - acc: 0.7824
# Epoch 117: val_acc did not improve from 0.76981
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4549 - acc: 0.7818 - val_loss: 0.5148 - val_acc: 0.7698
# Epoch 118/1000
# 286/297 [===========================>..] - ETA: 0s - loss: 0.4588 - acc: 0.7769
# Epoch 118: val_acc did not improve from 0.76981
# 297/297 [==============================] - 2s 7ms/step - loss: 0.4594 - acc: 0.7763 - val_loss: 0.5348 - val_acc: 0.7559
# Epoch 119/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4606 - acc: 0.7802
# Epoch 119: val_acc did not improve from 0.76981
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4617 - acc: 0.7791 - val_loss: 0.5223 - val_acc: 0.7563
# Epoch 120/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4530 - acc: 0.7788
# Epoch 120: val_acc did not improve from 0.76981
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4538 - acc: 0.7782 - val_loss: 0.5314 - val_acc: 0.7656
# Epoch 121/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4615 - acc: 0.7770
# Epoch 121: val_acc did not improve from 0.76981
# 297/297 [==============================] - 2s 7ms/step - loss: 0.4616 - acc: 0.7768 - val_loss: 0.5267 - val_acc: 0.7605
# Epoch 122/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4605 - acc: 0.7803
# Epoch 122: val_acc did not improve from 0.76981
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4603 - acc: 0.7805 - val_loss: 0.5247 - val_acc: 0.7669
# Epoch 123/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4621 - acc: 0.7827
# Epoch 123: val_acc did not improve from 0.76981
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4640 - acc: 0.7817 - val_loss: 0.5323 - val_acc: 0.7605
# Epoch 124/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4546 - acc: 0.7806
# Epoch 124: val_acc did not improve from 0.76981
# 297/297 [==============================] - 3s 9ms/step - loss: 0.4551 - acc: 0.7805 - val_loss: 0.5316 - val_acc: 0.7618
# Epoch 125/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4580 - acc: 0.7792
# Epoch 125: val_acc did not improve from 0.76981
# 297/297 [==============================] - 3s 11ms/step - loss: 0.4579 - acc: 0.7793 - val_loss: 0.5281 - val_acc: 0.7597
# Epoch 126/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.4592 - acc: 0.7798
# Epoch 126: val_acc did not improve from 0.76981
# 297/297 [==============================] - 2s 8ms/step - loss: 0.4592 - acc: 0.7798 - val_loss: 0.5219 - val_acc: 0.7631
# Epoch 127/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4536 - acc: 0.7799
# Epoch 127: val_acc improved from 0.76981 to 0.77024, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 7ms/step - loss: 0.4546 - acc: 0.7789 - val_loss: 0.5199 - val_acc: 0.7702
# Epoch 128/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.4536 - acc: 0.7844
# Epoch 128: val_acc did not improve from 0.77024
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4549 - acc: 0.7833 - val_loss: 0.5235 - val_acc: 0.7622
# Epoch 129/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4550 - acc: 0.7806
# Epoch 129: val_acc did not improve from 0.77024
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4555 - acc: 0.7806 - val_loss: 0.5280 - val_acc: 0.7643
# Epoch 130/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4505 - acc: 0.7851
# Epoch 130: val_acc improved from 0.77024 to 0.77234, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4511 - acc: 0.7847 - val_loss: 0.5213 - val_acc: 0.7723
# Epoch 131/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4551 - acc: 0.7798
# Epoch 131: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4556 - acc: 0.7790 - val_loss: 0.5274 - val_acc: 0.7690
# Epoch 132/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.4545 - acc: 0.7852
# Epoch 132: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4546 - acc: 0.7844 - val_loss: 0.5205 - val_acc: 0.7656
# Epoch 133/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4481 - acc: 0.7828
# Epoch 133: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 7ms/step - loss: 0.4482 - acc: 0.7827 - val_loss: 0.5185 - val_acc: 0.7648
# Epoch 134/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.4479 - acc: 0.7815
# Epoch 134: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4485 - acc: 0.7812 - val_loss: 0.5304 - val_acc: 0.7610
# Epoch 135/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.4579 - acc: 0.7786
# Epoch 135: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4577 - acc: 0.7785 - val_loss: 0.5363 - val_acc: 0.7681
# Epoch 136/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.4483 - acc: 0.7826
# Epoch 136: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4486 - acc: 0.7818 - val_loss: 0.5249 - val_acc: 0.7626
# Epoch 137/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4519 - acc: 0.7854
# Epoch 137: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4533 - acc: 0.7853 - val_loss: 0.5256 - val_acc: 0.7681
# Epoch 138/1000
# 286/297 [===========================>..] - ETA: 0s - loss: 0.4545 - acc: 0.7823
# Epoch 138: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4555 - acc: 0.7809 - val_loss: 0.5265 - val_acc: 0.7614
# Epoch 139/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4562 - acc: 0.7762
# Epoch 139: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4561 - acc: 0.7763 - val_loss: 0.5256 - val_acc: 0.7677
# Epoch 140/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.4499 - acc: 0.7837
# Epoch 140: val_acc did not improve from 0.77234
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4505 - acc: 0.7831 - val_loss: 0.5288 - val_acc: 0.7618
# Epoch 141/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.4505 - acc: 0.7874
# Epoch 141: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4505 - acc: 0.7874 - val_loss: 0.5174 - val_acc: 0.7614
# Epoch 142/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.4475 - acc: 0.7845
# Epoch 142: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4475 - acc: 0.7845 - val_loss: 0.5318 - val_acc: 0.7572
# Epoch 143/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.4512 - acc: 0.7854
# Epoch 143: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4510 - acc: 0.7853 - val_loss: 0.5215 - val_acc: 0.7656
# Epoch 144/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.4501 - acc: 0.7795
# Epoch 144: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4501 - acc: 0.7795 - val_loss: 0.5231 - val_acc: 0.7580
# Epoch 145/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4488 - acc: 0.7855
# Epoch 145: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4486 - acc: 0.7856 - val_loss: 0.5128 - val_acc: 0.7639
# Epoch 146/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.4485 - acc: 0.7846
# Epoch 146: val_acc did not improve from 0.77234
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4493 - acc: 0.7834 - val_loss: 0.5273 - val_acc: 0.7576
# Epoch 147/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.4431 - acc: 0.7879
# Epoch 147: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4441 - acc: 0.7865 - val_loss: 0.5282 - val_acc: 0.7656
# Epoch 148/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4452 - acc: 0.7878
# Epoch 148: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4456 - acc: 0.7871 - val_loss: 0.5408 - val_acc: 0.7635
# Epoch 149/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.4460 - acc: 0.7818
# Epoch 149: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4463 - acc: 0.7813 - val_loss: 0.5403 - val_acc: 0.7605
# Epoch 150/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.4526 - acc: 0.7779
# Epoch 150: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4528 - acc: 0.7775 - val_loss: 0.5412 - val_acc: 0.7618
# Epoch 151/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.4450 - acc: 0.7903
# Epoch 151: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4462 - acc: 0.7893 - val_loss: 0.5447 - val_acc: 0.7572
# Epoch 152/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.4466 - acc: 0.7873
# Epoch 152: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4478 - acc: 0.7862 - val_loss: 0.5404 - val_acc: 0.7572
# Epoch 153/1000
# 286/297 [===========================>..] - ETA: 0s - loss: 0.4399 - acc: 0.7880
# Epoch 153: val_acc did not improve from 0.77234
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4420 - acc: 0.7866 - val_loss: 0.5181 - val_acc: 0.7723
# Epoch 154/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4476 - acc: 0.7861
# Epoch 154: val_acc did not improve from 0.77234
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4475 - acc: 0.7862 - val_loss: 0.5232 - val_acc: 0.7677
# Epoch 155/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.4496 - acc: 0.7823
# Epoch 155: val_acc did not improve from 0.77234
# 297/297 [==============================] - 1s 5ms/step - loss: 0.4497 - acc: 0.7822 - val_loss: 0.5312 - val_acc: 0.7677
# Epoch 156/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.4419 - acc: 0.7868
# Epoch 156: val_acc improved from 0.77234 to 0.77698, saving model to train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam\1\256\best_model.h5
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4428 - acc: 0.7863 - val_loss: 0.5190 - val_acc: 0.7770
# Epoch 157/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.4465 - acc: 0.7868
# Epoch 157: val_acc did not improve from 0.77698
# 297/297 [==============================] - 2s 5ms/step - loss: 0.4472 - acc: 0.7864 - val_loss: 0.5270 - val_acc: 0.7753
# Epoch 158/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.4492 - acc: 0.7849
# Epoch 158: val_acc did not improve from 0.77698
# 297/297 [==============================] - 2s 7ms/step - loss: 0.4505 - acc: 0.7845 - val_loss: 0.5209 - val_acc: 0.7635
# Epoch 159/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.4455 - acc: 0.7843
# Epoch 159: val_acc did not improve from 0.77698
# 297/297 [==============================] - 3s 10ms/step - loss: 0.4455 - acc: 0.7843 - val_loss: 0.5320 - val_acc: 0.7614
# Epoch 160/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4424 - acc: 0.7872
# Epoch 160: val_acc did not improve from 0.77698
# 297/297 [==============================] - 2s 8ms/step - loss: 0.4426 - acc: 0.7872 - val_loss: 0.5313 - val_acc: 0.7618
# Epoch 161/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4418 - acc: 0.7879
# Epoch 161: val_acc did not improve from 0.77698
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4418 - acc: 0.7880 - val_loss: 0.5337 - val_acc: 0.7664
# Epoch 162/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4449 - acc: 0.7881
# Epoch 162: val_acc did not improve from 0.77698
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4448 - acc: 0.7882 - val_loss: 0.5419 - val_acc: 0.7673
# Epoch 163/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4440 - acc: 0.7862
# Epoch 163: val_acc did not improve from 0.77698
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4441 - acc: 0.7862 - val_loss: 0.5400 - val_acc: 0.7677
# Epoch 164/1000
# 285/297 [===========================>..] - ETA: 0s - loss: 0.4381 - acc: 0.7941
# Epoch 164: val_acc did not improve from 0.77698
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4386 - acc: 0.7926 - val_loss: 0.5289 - val_acc: 0.7715
# Epoch 165/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4406 - acc: 0.7849
# Epoch 165: val_acc did not improve from 0.77698
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4406 - acc: 0.7850 - val_loss: 0.5286 - val_acc: 0.7584
# Epoch 166/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.4469 - acc: 0.7855
# Epoch 166: val_acc did not improve from 0.77698
# 297/297 [==============================] - 2s 6ms/step - loss: 0.4469 - acc: 0.7855 - val_loss: 0.5335 - val_acc: 0.7635
# Epoch 167/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.4362 - acc: 0.7885
# Epoch 167: val_acc did not improve from 0.77698
# 297/297 [==============================] - 2s 7ms/step - loss: 0.4367 - acc: 0.7881 - val_loss: 0.5251 - val_acc: 0.7715
# Epoch 168/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.4449 - acc: 0.7859
# Epoch 168: val_acc did not improve from 0.77698
# ...
# Epoch 566/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.3898 - acc: 0.8142
# Epoch 566: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3897 - acc: 0.8141 - val_loss: 0.9724 - val_acc: 0.7790
# Epoch 567/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.3918 - acc: 0.8169
# Epoch 567: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3908 - acc: 0.8173 - val_loss: 0.9064 - val_acc: 0.7819
# Epoch 568/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.3981 - acc: 0.8148
# Epoch 568: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3982 - acc: 0.8144 - val_loss: 0.8716 - val_acc: 0.7769
# Epoch 569/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.3917 - acc: 0.8144
# Epoch 569: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3919 - acc: 0.8141 - val_loss: 0.9284 - val_acc: 0.7879
# Epoch 570/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.3876 - acc: 0.8131
# Epoch 570: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3873 - acc: 0.8132 - val_loss: 0.9835 - val_acc: 0.7769
# Epoch 571/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.3885 - acc: 0.8171
# Epoch 571: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3884 - acc: 0.8171 - val_loss: 0.9132 - val_acc: 0.7803
# Epoch 572/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.3876 - acc: 0.8144
# Epoch 572: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 9ms/step - loss: 0.3878 - acc: 0.8141 - val_loss: 0.9212 - val_acc: 0.7828
# Epoch 573/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.3879 - acc: 0.8135
# Epoch 573: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3876 - acc: 0.8136 - val_loss: 1.0304 - val_acc: 0.7883
# Epoch 574/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.3984 - acc: 0.8145
# Epoch 574: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 10ms/step - loss: 0.3979 - acc: 0.8142 - val_loss: 1.0414 - val_acc: 0.7803
# Epoch 575/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.3880 - acc: 0.8197
# Epoch 575: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 9ms/step - loss: 0.3878 - acc: 0.8198 - val_loss: 0.8960 - val_acc: 0.7824
# Epoch 576/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.3968 - acc: 0.8114
# Epoch 576: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 9ms/step - loss: 0.3964 - acc: 0.8119 - val_loss: 0.9906 - val_acc: 0.7798
# Epoch 577/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.3866 - acc: 0.8157
# Epoch 577: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 10ms/step - loss: 0.3866 - acc: 0.8156 - val_loss: 0.8939 - val_acc: 0.7849
# Epoch 578/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.3880 - acc: 0.8168
# Epoch 578: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 10ms/step - loss: 0.3880 - acc: 0.8168 - val_loss: 0.9330 - val_acc: 0.7790
# Epoch 579/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.3908 - acc: 0.8121
# Epoch 579: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 9ms/step - loss: 0.3908 - acc: 0.8121 - val_loss: 0.9147 - val_acc: 0.7794
# Epoch 580/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.3970 - acc: 0.8126
# Epoch 580: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 10ms/step - loss: 0.3961 - acc: 0.8128 - val_loss: 0.9971 - val_acc: 0.7765
# Epoch 581/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.3944 - acc: 0.8149
# Epoch 581: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3965 - acc: 0.8144 - val_loss: 0.9103 - val_acc: 0.7756
# Epoch 582/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.3951 - acc: 0.8127
# Epoch 582: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3950 - acc: 0.8127 - val_loss: 0.9251 - val_acc: 0.7769
# Epoch 583/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.3888 - acc: 0.8168
# Epoch 583: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3885 - acc: 0.8167 - val_loss: 0.8594 - val_acc: 0.7782
# Epoch 584/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.3898 - acc: 0.8150
# Epoch 584: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3906 - acc: 0.8155 - val_loss: 0.9027 - val_acc: 0.7744
# Epoch 585/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.3893 - acc: 0.8145
# Epoch 585: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3895 - acc: 0.8144 - val_loss: 0.9691 - val_acc: 0.7879
# Epoch 586/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.3893 - acc: 0.8178
# Epoch 586: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3884 - acc: 0.8179 - val_loss: 1.0560 - val_acc: 0.7748
# Epoch 587/1000
# 288/297 [============================>.] - ETA: 0s - loss: 0.3866 - acc: 0.8183
# Epoch 587: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3870 - acc: 0.8177 - val_loss: 0.8332 - val_acc: 0.7828
# Epoch 588/1000
# 289/297 [============================>.] - ETA: 0s - loss: 0.3892 - acc: 0.8174
# Epoch 588: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3893 - acc: 0.8175 - val_loss: 0.9111 - val_acc: 0.7841
# Epoch 589/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.3958 - acc: 0.8133
# Epoch 589: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3955 - acc: 0.8136 - val_loss: 1.0233 - val_acc: 0.7786
# Epoch 590/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.3879 - acc: 0.8184
# Epoch 590: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3875 - acc: 0.8187 - val_loss: 1.1990 - val_acc: 0.7790
# Epoch 591/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.3968 - acc: 0.8100
# Epoch 591: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3966 - acc: 0.8101 - val_loss: 0.9541 - val_acc: 0.7853
# Epoch 592/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.3901 - acc: 0.8119
# Epoch 592: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3897 - acc: 0.8123 - val_loss: 1.0387 - val_acc: 0.7824
# Epoch 593/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.3919 - acc: 0.8156
# Epoch 593: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3926 - acc: 0.8155 - val_loss: 1.0449 - val_acc: 0.7722
# Epoch 594/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.3916 - acc: 0.8150
# Epoch 594: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3916 - acc: 0.8150 - val_loss: 1.0264 - val_acc: 0.7836
# Epoch 595/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.3836 - acc: 0.8143
# Epoch 595: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3842 - acc: 0.8141 - val_loss: 0.9537 - val_acc: 0.7773
# Epoch 596/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.3838 - acc: 0.8157
# Epoch 596: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3831 - acc: 0.8162 - val_loss: 1.1051 - val_acc: 0.7807
# Epoch 597/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.3909 - acc: 0.8101
# Epoch 597: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3909 - acc: 0.8098 - val_loss: 0.9896 - val_acc: 0.7824
# Epoch 598/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.3873 - acc: 0.8185
# Epoch 598: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3876 - acc: 0.8186 - val_loss: 0.9526 - val_acc: 0.7870
# Epoch 599/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.3862 - acc: 0.8178
# Epoch 599: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3860 - acc: 0.8179 - val_loss: 1.0343 - val_acc: 0.7786
# Epoch 600/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.3864 - acc: 0.8133
# Epoch 600: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3864 - acc: 0.8134 - val_loss: 0.9973 - val_acc: 0.7824
# Epoch 601/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.3900 - acc: 0.8154
# Epoch 601: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3903 - acc: 0.8154 - val_loss: 0.9604 - val_acc: 0.7777
# Epoch 602/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.3832 - acc: 0.8146
# Epoch 602: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3834 - acc: 0.8144 - val_loss: 0.9661 - val_acc: 0.7798
# Epoch 603/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.3875 - acc: 0.8099
# Epoch 603: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3877 - acc: 0.8102 - val_loss: 1.0769 - val_acc: 0.7819
# Epoch 604/1000
# 287/297 [===========================>..] - ETA: 0s - loss: 0.3994 - acc: 0.8104
# Epoch 604: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3981 - acc: 0.8108 - val_loss: 0.9646 - val_acc: 0.7777
# Epoch 605/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.3875 - acc: 0.8173
# Epoch 605: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3884 - acc: 0.8171 - val_loss: 0.9434 - val_acc: 0.7777
# Epoch 606/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.3889 - acc: 0.8131
# Epoch 606: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3894 - acc: 0.8127 - val_loss: 0.9835 - val_acc: 0.7786
# Epoch 607/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.3946 - acc: 0.8155
# Epoch 607: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 9ms/step - loss: 0.3940 - acc: 0.8157 - val_loss: 1.0622 - val_acc: 0.7832
# Epoch 608/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.3976 - acc: 0.8116
# Epoch 608: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3973 - acc: 0.8117 - val_loss: 1.0112 - val_acc: 0.7832
# Epoch 609/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.3872 - acc: 0.8158
# Epoch 609: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 10ms/step - loss: 0.3867 - acc: 0.8160 - val_loss: 0.8775 - val_acc: 0.7803
# Epoch 610/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.3852 - acc: 0.8160
# Epoch 610: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3846 - acc: 0.8160 - val_loss: 0.9802 - val_acc: 0.7815
# Epoch 611/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.3908 - acc: 0.8124
# Epoch 611: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3904 - acc: 0.8127 - val_loss: 0.9296 - val_acc: 0.7803
# Epoch 612/1000
# 295/297 [============================>.] - ETA: 0s - loss: 0.3880 - acc: 0.8159
# Epoch 612: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 9ms/step - loss: 0.3878 - acc: 0.8161 - val_loss: 1.1517 - val_acc: 0.7786
# Epoch 613/1000
# 292/297 [============================>.] - ETA: 0s - loss: 0.3868 - acc: 0.8152
# Epoch 613: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3870 - acc: 0.8150 - val_loss: 1.1279 - val_acc: 0.7794
# Epoch 614/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.3912 - acc: 0.8181
# Epoch 614: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3911 - acc: 0.8182 - val_loss: 1.0798 - val_acc: 0.7832
# Epoch 615/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.3893 - acc: 0.8146
# Epoch 615: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3891 - acc: 0.8147 - val_loss: 1.0587 - val_acc: 0.7727
# Epoch 616/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.3945 - acc: 0.8163
# Epoch 616: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 9ms/step - loss: 0.3941 - acc: 0.8164 - val_loss: 0.9159 - val_acc: 0.7790
# Epoch 617/1000
# 297/297 [==============================] - ETA: 0s - loss: 0.3962 - acc: 0.8128
# Epoch 617: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 9ms/step - loss: 0.3962 - acc: 0.8128 - val_loss: 1.0691 - val_acc: 0.7773
# Epoch 618/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.3832 - acc: 0.8190
# Epoch 618: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3825 - acc: 0.8194 - val_loss: 1.0106 - val_acc: 0.7841
# Epoch 619/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.3988 - acc: 0.8112
# Epoch 619: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3987 - acc: 0.8113 - val_loss: 1.0014 - val_acc: 0.7735
# Epoch 620/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.3865 - acc: 0.8159
# Epoch 620: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3866 - acc: 0.8160 - val_loss: 1.0517 - val_acc: 0.7798
# Epoch 621/1000
# 294/297 [============================>.] - ETA: 0s - loss: 0.3919 - acc: 0.8169
# Epoch 621: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3915 - acc: 0.8172 - val_loss: 1.1216 - val_acc: 0.7841
# Epoch 622/1000
# 291/297 [============================>.] - ETA: 0s - loss: 0.3903 - acc: 0.8173
# Epoch 622: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 7ms/step - loss: 0.3904 - acc: 0.8177 - val_loss: 1.0518 - val_acc: 0.7731
# Epoch 623/1000
# 290/297 [============================>.] - ETA: 0s - loss: 0.3863 - acc: 0.8171
# Epoch 623: val_acc did not improve from 0.79418
# 297/297 [==============================] - 2s 8ms/step - loss: 0.3865 - acc: 0.8168 - val_loss: 1.1415 - val_acc: 0.7756
# Epoch 624/1000
# 296/297 [============================>.] - ETA: 0s - loss: 0.3913 - acc: 0.8166
# Epoch 624: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 10ms/step - loss: 0.3913 - acc: 0.8167 - val_loss: 1.0139 - val_acc: 0.7765
# Epoch 625/1000
# 293/297 [============================>.] - ETA: 0s - loss: 0.3920 - acc: 0.8186
# Epoch 625: val_acc did not improve from 0.79418
# 297/297 [==============================] - 3s 10ms/step - loss: 0.3913 - acc: 0.8187 - val_loss: 1.0718 - val_acc: 0.7803
# 93/93 [==============================] - 1s 4ms/step - loss: 0.8796 - acc: 0.7818

# %%
# Load Best Model
LAG = 256

test_dir = f"datasets/tf_batch/rwb_f_only/segment_{SEGMENT_TIME} seconds/test_{LAG}"
test_ds = tf.data.Dataset.load(test_dir)
model_dir = [f"train_logs/logs10/RWB_F_ONLY_ANN_512_256_Adam/{i}/{LAG}/best_model.h5" for i in range(1,6)]

# %%
flattened_test = test_ds.unbatch()
test_data = list(flattened_test.as_numpy_iterator())

# %%
test_data_value = np.array([test_data[i][0] for i in range(len(test_data))])
test_data_label = np.array([test_data[i][1] for i in range(len(test_data))])

# %%
test_data_value.reshape(test_data_value.shape[0], -1).shape
# Out:
# (2965, 42)

# %%
results = []

for i, model_path in enumerate(model_dir):
    model = keras.models.load_model(model_path)
    loss, acc = model.evaluate(test_ds)
    print(loss, acc)
    pred = model.predict(test_data_value.reshape(test_data_value.shape[0], -1))
    results.append(pred)
# Out:
# 93/93 [==============================] - 1s 5ms/step - loss: 0.6784 - acc: 0.7835
# 0.6783757209777832 0.7834738492965698
# 93/93 [==============================] - 0s 2ms/step
# 93/93 [==============================] - 1s 4ms/step - loss: 0.5753 - acc: 0.7771
# 0.5752947330474854 0.7770657539367676
# 93/93 [==============================] - 0s 2ms/step
# 93/93 [==============================] - 1s 5ms/step - loss: 0.5450 - acc: 0.7858
# 0.5449562668800354 0.7858347296714783
# 93/93 [==============================] - 0s 3ms/step
# 93/93 [==============================] - 1s 4ms/step - loss: 0.7000 - acc: 0.7815
# 0.6999697685241699 0.7814502716064453
# 93/93 [==============================] - 0s 3ms/step
# 93/93 [==============================] - 1s 4ms/step - loss: 0.7823 - acc: 0.7895
# 0.7822746634483337 0.7895447015762329
# 93/93 [==============================] - 0s 2ms/step

# %%
from sklearn import metrics

for i, res in enumerate(results, 1):
    pred = np.round(res.reshape(res.shape[0])).astype(bool)
    confusion_matrix = metrics.confusion_matrix(test_data_label.astype(bool), pred)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['normal', 'autism'])
    cm_display.plot()
    plt.title(f"Result: RWB ANN (512,256)(Adam) lag 256 for model in fold {i}")
    plt.show()

# %%
for i, res in enumerate(results, 1):
    pred = np.round(res.reshape(res.shape[0])).astype(bool)
    test_data_label = test_data_label.astype(bool)  

    print(f"Result: RWB ANN (512,256)(RMSprop) lag 128 for model in fold {i}")

    TP = np.sum((test_data_label == True) & (pred == True))
    FP = np.sum((test_data_label == False) & (pred == True))
    TN = np.sum((test_data_label == False) & (pred == False))
    FN = np.sum((test_data_label == True) & (pred == False))  

    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"Accuracy: {accuracy}")
    print(f"F1-score: {f1_score}")
    print("\n")
# Out:
# Result: RWB ANN (512,256)(RMSprop) lag 128 for model in fold 1
# Precision: 0.7725631768953068
# Recall: 0.9625187406296851
# Accuracy: 0.7834738617200675
# F1-score: 0.8571428571428571
#
#
# Result: RWB ANN (512,256)(RMSprop) lag 128 for model in fold 2
# Precision: 0.7671451355661882
# Recall: 0.9615192403798101
# Accuracy: 0.7770657672849915
# F1-score: 0.853404302506099
#
#
# Result: RWB ANN (512,256)(RMSprop) lag 128 for model in fold 3
# Precision: 0.7706022187004754
# Recall: 0.9720139930034982
# Accuracy: 0.7858347386172007
# F1-score: 0.8596685082872928
#
#
# Result: RWB ANN (512,256)(RMSprop) lag 128 for model in fold 4
# Precision: 0.7715776796467282
# Recall: 0.960519740129935
# Accuracy: 0.7814502529510962
# F1-score: 0.8557435440783616
#
#
# Result: RWB ANN (512,256)(RMSprop) lag 128 for model in fold 5
# Precision: 0.7752898840463814
# Recall: 0.9690154922538731
# Accuracy: 0.7895446880269814
# F1-score: 0.8613949355841848

# %%
# for log_dir in log_dirs:
#     recap = pd.DataFrame(index=lags, columns=folds)
#     training_time = pd.DataFrame(index=lags, columns=time_measured)
#     for fold in range(1,3):
#         for lag in lags:
#             if fold == 2:
#                 train_dir, test_dir = test_dir, train_dir
            
#             train_temp_dir = train_dir + '_' + str(lag)
#             test_temp_dir = test_dir + '_' + str(lag)

#             train = get_batch(train_temp_dir)
#             test_ds = get_batch(test_temp_dir)

#             train_size = int(len(list(train.as_numpy_iterator()))*0.8)
#             train_ds = train.take(train_size)
#             val_ds = train.skip(train_size)

#             log_path = os.path.join(log_dir, str(fold), str(lag))

#             model = create_model()
#             model.summary()

#             model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['acc'])

#             cpu_start = time.process_time()
#             wt_start = time.time()

#             history = model.fit(train_ds, epochs=epochs, validation_data=(val_ds), callbacks = myCallbacks(log_path))

#             wt_end = time.time()
#             cpu_end = time.process_time()
#             wall_time = wt_end - wt_start
#             cpu_time = cpu_end - cpu_start
#             training_time.loc[lag, 'CPU_Time'+ '_' + str(fold)] = cpu_time
#             training_time.loc[lag, 'Wall_Time'+ '_' + str(fold)] = wall_time

#             results = model.evaluate(test_ds, callbacks = myCallbacks(log_path))

#             recap.loc[lag, 'train'+ '_' + str(fold)] = history.history['acc']
#             recap.loc[lag, 'test'+ '_' + str(fold)] = results[1]
#             recap.loc[lag, 'epoch'+ '_' + str(fold)] = len(history.history['acc'])
#     log_dir = os.path.join(log_dir,'Recap')
#     if not os.path.exists(log_dir):
#         os.makedirs(log_dir)
#     recap.to_csv(os.path.join(log_dir,'recap.csv'))
#     training_time.to_csv(os.path.join(log_dir,'Training_time.csv'))

# %%
# %load_ext tensorboard

# %%
! tensorboard --logdir c:/Users/farra/Documents/Pribadi/EEG/EEG-Autism-Classification --port=8000
# Out:
# ^C

# %%
# %tensorboard --logdir logs --port=8000

# %%
! cd
# Out:
# c:\Users\farra\Documents\Pribadi\EEG\EEG-Autism-Classification
