# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import preprocessing, model_selection
import csv
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import time
import json
import random

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.10.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Data Preparation

# %%
def get_dataset(directory, lag, excluded_name=[]):
    data = pd.DataFrame(columns=['data', 'label'])
    for foldername in os.listdir(directory):        
        folder = os.path.join(directory, foldername)
        # print(folder)
        if str(lag) in folder:
            # print(os.listdir(folder))
            for name in os.listdir(folder):
                if name in excluded_name:
                    # print(name)
                    continue
                filename = os.path.join(folder, name)
                # print(filename)
                for files in os.listdir(filename):
                    rel_path = os.path.join(filename, files)
                    # print(rel_path)
                    temp_label = folder
                    if "autism" in temp_label:
                        label = 'autism'
                    else:
                        label = 'normal'

                    temp_data = pd.DataFrame(columns=['data', 'label'], index=[0])

                    rwb = np.load(rel_path)
                    rwb.astype(np.float64).reshape(-1,1)
                                    
                    temp_data.loc[0, "data"] = rwb
                    temp_data['label'] = label
                    data = pd.concat([data, temp_data], ignore_index=True)
    label_map = {"autism": 1, "normal": 0}
    data['label_map'] = data['label'].map(label_map)      
    return data

# %%
def remove_missing_value(data):
    series_list = np.vstack(data["data"].values)
    labels_list = data["label_map"].values    
    missing_indices = np.where(np.isnan(series_list).any(axis=1))[0]

    clean_data = data.drop(index=data.index[missing_indices])
    return clean_data

# %%
# temp_data = pd.DataFrame(columns=['data', 'label'], index=[0])
# rwb = np.load("datasets/features/rwb/segment_1 seconds/autism_256/bader/Bader_segment_100.csv_bispectrum.npy")
# rwb.astype(np.float64).reshape(-1,1)
# temp_data.loc[0, "data"] = rwb
# temp_data['label'] = "autism"

# %%
def save_dataset(data, des_path):
    if not os.path.exists(des_path):
        os.makedirs(des_path)
    data.save(des_path)

# %%
def get_train_test(data, train_split: float):
    train_x, test_x, train_y, test_y = model_selection.train_test_split(
        data['data'],
        data[['label', 'label_map']],
        train_size=train_split,
        stratify=data['label_map']
    )

    train_df = pd.DataFrame(columns=['data', 'label', 'label_map'])
    test_df = pd.DataFrame(columns=['data', 'label', 'label_map'])

    train_df["data"] = train_x
    train_df[['label', 'label_map']] = train_y

    test_df["data"] = test_x
    test_df[['label', 'label_map']] = test_y

    return train_df, test_df

# %%
def get_batch(data):
    # loading extracted feature & label
    # x = get_dataset(path, lag, excluded_name)

    # scaler = preprocessing.MinMaxScaler()

    series_list = np.vstack(data["data"].values)

    # series_list = series_list.reshape(-1, 366, 1)

    labels_list = data["label_map"].values
        
    # y = keras.utils.to_categorical(y[0])
    dataset = tf.data.Dataset.from_tensor_slices((series_list,labels_list))
    dataset = dataset.shuffle(len(labels_list))

    # train_size = int(train_split * len(labels_list))  
    # test_size = len(labels_list) - train_size  

    # train_dataset = dataset.take(train_size)
    # test_dataset = dataset.skip(train_size)

    BATCH_SIZE = 32

    dataset = dataset.batch(BATCH_SIZE)

    return dataset

# %%
def relative_transform(data):    
    series_list = np.vstack(data["data"].values)
    labels_list = data["label_map"].values  

    relative_energy = np.zeros([series_list.shape[0], series_list.shape[1]])
    for i, series in enumerate(series_list):
        total_energy = np.sum(series)
        relative_energy[i] = [(s / total_energy) * 100 for s in series]
    relative_energy_list = [arr for arr in relative_energy]
    data["data"] = relative_energy_list
    return data

# %%
# train_x, test_x, train_y, test_y = model_selection.train_test_split(
#         data['data'],
#         data[['label', 'label_map']],
#         train_size=0.8,
#         stratify=data['label_map']
#     )

# train_df = pd.DataFrame(columns=['data', 'label', 'label_map'])
# test_df = pd.DataFrame(columns=['data', 'label', 'label_map'])

# train_df["data"] = train_x
# train_df[['label', 'label_map']] = train_y

# test_df["data"] = test_x
# test_df[['label', 'label_map']] = test_y

# %%
# excluded = ["zyad"]
# data = get_dataset(data_dir, 256, excluded_name=excluded)

# %%
# temp = data["data"].values
# series_list = np.vstack(temp)
# series_list = series_list.reshape(-1, 96, 1)

# %%
SEGMENT_TIME = 1

data_dir = f"datasets/features/bispectrum_pyramid/segment_{SEGMENT_TIME} seconds"

train_dir = f"datasets/tf_batch/bispectrum_pyramid/segment_{SEGMENT_TIME} seconds/train"
test_dir = f"datasets/tf_batch/bispectrum_pyramid/segment_{SEGMENT_TIME} seconds/test"

# %%
# excluded = ["zyad"]
# data = get_dataset(data_dir, 256, excluded)

# %%
# data.shape[0]

# %%
# series_list = np.vstack(data["data"].values)
# labels_list = data["label_map"].values    
# missing_indices = np.where(np.isnan(series_list).any(axis=1))[0]

# clean_data = data.drop(index=data.index[missing_indices])

# %%
# clean_data.shape[0]

# %%
excluded = ["zyad"]
train_split = 0.8
LAG = [256, 128, 64]

for lag in LAG:
    data = get_dataset(data_dir, lag, excluded)
    print(data.shape)
    data = relative_transform(data)
    data = remove_missing_value(data)
    print(data.shape)
    train_data, test_data = get_train_test(data, train_split)
    print("train: ", train_data.shape)
    print("test: ", test_data.shape)
    train_batch = get_batch(train_data)
    test_batch = get_batch(test_data)
    tf.data.Dataset.save(train_batch, f"{train_dir}_{lag}")
    tf.data.Dataset.save(test_batch, f"{test_dir}_{lag}")
# Out:
# (15434, 3)
# C:\Users\farra\AppData\Local\Temp\ipykernel_2592\3426103326.py:8: RuntimeWarning: invalid value encountered in scalar divide
#   relative_energy[i] = [(s / total_energy) * 100 for s in series]
# (15399, 3)
# train:  (12319, 3)
# test:  (3080, 3)
# (15434, 3)
# C:\Users\farra\AppData\Local\Temp\ipykernel_2592\3426103326.py:8: RuntimeWarning: invalid value encountered in scalar divide
#   relative_energy[i] = [(s / total_energy) * 100 for s in series]
# (15399, 3)
# train:  (12319, 3)
# test:  (3080, 3)
# (15434, 3)
# C:\Users\farra\AppData\Local\Temp\ipykernel_2592\3426103326.py:8: RuntimeWarning: invalid value encountered in scalar divide
#   relative_energy[i] = [(s / total_energy) * 100 for s in series]
# (15399, 3)
# train:  (12319, 3)
# test:  (3080, 3)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Load the CSV file into a DataFrame
LAG = [64]

signal = np.load(f"datasets/features/bispectrum_pyramid/segment_{SEGMENT_TIME} seconds/normal_{LAG[0]}/amer/Amer_segment_1.csv_bispectrum.npy")
# Extract the signal values from the DataFrame

# Create a time axis for the signal
t = range(len(signal))

fig, ax = plt.subplots(figsize=(10, 5))
# Plot the signal
ax.plot(t, signal)
ax.set_xlabel('Time (samples)')
ax.set_ylabel('Signal amplitude')
ax.set_title('Signal plot')
plt.show()

# %%
rel_signal = np.array([(s / np.sum(signal)) * 100 for s in signal])

print(rel_signal.shape)
t = range(len(signal))

fig, ax = plt.subplots(figsize=(10, 5))
# Plot the signal
ax.plot(t, rel_signal)
ax.set_xlabel('Time (samples)')
ax.set_ylabel('Signal amplitude')
ax.set_title('Signal plot')
plt.show()
# Out:
# (240,)

# %% [markdown]
# ### Model Definition

# %%
input_size = 240

def create_model():
    model = keras.models.Sequential()

    model.add(layers.Input(shape=(input_size,)))
    model.add(layers.Reshape((input_size, 1)))

    model.add(layers.Flatten())

    model.add(layers.Dense(512, activation="relu"))

    model.add(layers.Dropout(0.5))

    model.add(layers.Dense(256, activation="relu"))

    model.add(layers.Dropout(0.5))

    model.add(layers.Dense(1, activation="sigmoid"))

    return model

# %%
sample_model = create_model()
sample_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 240, 1)            0
#
#  flatten (Flatten)           (None, 240)               0
#
#  dense (Dense)               (None, 512)               123392
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 254,977
# Trainable params: 254,977
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Define Callbacks

# %%
def myCallbacks(log_dir):
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
    early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='acc',
    patience=50,
    mode='max')
    model_path = os.path.join(log_dir,'best_model.h5')
    mc = tf.keras.callbacks.ModelCheckpoint(model_path, monitor='val_acc', mode='max', verbose=1, save_best_only=True)
    return [tensorboard_callback, early_stopping, mc]

# %% [markdown]
# ### Main Program

# %%
lags = [256,128,64]
# folds = ['train_1', 'test_1', 'epoch_1', 'train_2', 'test_2', 'epoch_2']
time_measured = ['Wall_Time_1', 'CPU_Time_1', 'Wall_Time_2', 'CPU_Time_2']
epochs = 1000
log_dirs = [f"train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam"]

# %%
for log_dir in log_dirs:
    recap = pd.DataFrame(index=lags, columns=range(1, 6))
    training_time = pd.DataFrame(index=lags, columns=[f'CPU_Time_{i}' for i in range(1, 6)] + [f'Wall_Time_{i}' for i in range(1, 6)])

    for lag in lags:
        train_temp_dir = train_dir + '_' + str(lag)
        train = tf.data.Dataset.load(train_temp_dir)
        flattened_train = train.unbatch()

        train_data = list(flattened_train.as_numpy_iterator())
        train_size = len(list(train_data))

        kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=42)

        for fold, (train_index, val_index) in enumerate(kf.split(train_data), 1):
            train_fold_data = ([train_data[i][0] for i in train_index], [train_data[i][1] for i in train_index])
            val_fold_data = ([train_data[i][0] for i in val_index], [train_data[i][1] for i in val_index])

            train_fold = tf.data.Dataset.from_tensor_slices(train_fold_data).batch(32)
            val_fold = tf.data.Dataset.from_tensor_slices(val_fold_data).batch(32)

            log_path = os.path.join(log_dir, str(fold), str(lag))

            model = create_model()        
            model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['acc'])

            cpu_start = time.process_time()
            wt_start = time.time()

            history = model.fit(train_fold, epochs=epochs, validation_data=val_fold, callbacks=myCallbacks(log_path), verbose=2)

            wt_end = time.time()
            cpu_end = time.process_time()
            wall_time = wt_end - wt_start
            cpu_time = cpu_end - cpu_start

            training_time.loc[lag, f'CPU_Time_{fold}'] = cpu_time
            training_time.loc[lag, f'Wall_Time_{fold}'] = wall_time

            recap.loc[lag, fold] = history.history['acc'][-1]


    # Evaluate on the test dataset after cross-validation
    test_temp_dir = test_dir + '_' + str(lag)
    test_ds = tf.data.Dataset.load(test_temp_dir)
    results = model.evaluate(test_ds, callbacks=myCallbacks(log_path))

    recap[f'test_{lag}'] = results[1]

    log_recap_dir = os.path.join(log_dir, 'Recap')
    if not os.path.exists(log_recap_dir):
        os.makedirs(log_recap_dir)

    recap.to_csv(os.path.join(log_recap_dir, 'recap.csv'))
    training_time.to_csv(os.path.join(log_recap_dir, 'Training_time.csv'))
# Out:
# Epoch 1/1000
#
# Epoch 1: val_acc improved from -inf to 0.80844, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 3s - loss: 0.5665 - acc: 0.7400 - val_loss: 0.4415 - val_acc: 0.8084 - 3s/epoch - 11ms/step
# Epoch 2/1000
#
# Epoch 2: val_acc improved from 0.80844 to 0.83117, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.4385 - acc: 0.8030 - val_loss: 0.3856 - val_acc: 0.8312 - 1s/epoch - 4ms/step
# Epoch 3/1000
#
# Epoch 3: val_acc improved from 0.83117 to 0.85106, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.3857 - acc: 0.8319 - val_loss: 0.3441 - val_acc: 0.8511 - 1s/epoch - 4ms/step
# Epoch 4/1000
#
# Epoch 4: val_acc improved from 0.85106 to 0.87013, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.3507 - acc: 0.8472 - val_loss: 0.3146 - val_acc: 0.8701 - 1s/epoch - 4ms/step
# Epoch 5/1000
#
# Epoch 5: val_acc improved from 0.87013 to 0.87744, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.3235 - acc: 0.8634 - val_loss: 0.2951 - val_acc: 0.8774 - 1s/epoch - 4ms/step
# Epoch 6/1000
#
# Epoch 6: val_acc improved from 0.87744 to 0.89123, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.3056 - acc: 0.8726 - val_loss: 0.2766 - val_acc: 0.8912 - 1s/epoch - 4ms/step
# Epoch 7/1000
#
# Epoch 7: val_acc improved from 0.89123 to 0.89813, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.2888 - acc: 0.8780 - val_loss: 0.2505 - val_acc: 0.8981 - 1s/epoch - 4ms/step
# Epoch 8/1000
#
# Epoch 8: val_acc improved from 0.89813 to 0.90950, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.2747 - acc: 0.8884 - val_loss: 0.2355 - val_acc: 0.9095 - 1s/epoch - 4ms/step
# Epoch 9/1000
#
# Epoch 9: val_acc improved from 0.90950 to 0.91477, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.2570 - acc: 0.8945 - val_loss: 0.2224 - val_acc: 0.9148 - 1s/epoch - 4ms/step
# Epoch 10/1000
#
# Epoch 10: val_acc did not improve from 0.91477
# 308/308 - 1s - loss: 0.2518 - acc: 0.8976 - val_loss: 0.2201 - val_acc: 0.9144 - 1s/epoch - 4ms/step
# Epoch 11/1000
#
# Epoch 11: val_acc improved from 0.91477 to 0.91883, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.2517 - acc: 0.8956 - val_loss: 0.2141 - val_acc: 0.9188 - 1s/epoch - 4ms/step
# Epoch 12/1000
#
# Epoch 12: val_acc improved from 0.91883 to 0.92167, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.2319 - acc: 0.9048 - val_loss: 0.2055 - val_acc: 0.9217 - 1s/epoch - 4ms/step
# Epoch 13/1000
#
# Epoch 13: val_acc did not improve from 0.92167
# 308/308 - 1s - loss: 0.2287 - acc: 0.9074 - val_loss: 0.2021 - val_acc: 0.9164 - 1s/epoch - 4ms/step
# Epoch 14/1000
#
# Epoch 14: val_acc improved from 0.92167 to 0.92614, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.2214 - acc: 0.9125 - val_loss: 0.1925 - val_acc: 0.9261 - 1s/epoch - 4ms/step
# Epoch 15/1000
#
# Epoch 15: val_acc did not improve from 0.92614
# 308/308 - 1s - loss: 0.2199 - acc: 0.9093 - val_loss: 0.2002 - val_acc: 0.9249 - 1s/epoch - 3ms/step
# Epoch 16/1000
#
# Epoch 16: val_acc improved from 0.92614 to 0.92817, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.2102 - acc: 0.9146 - val_loss: 0.1961 - val_acc: 0.9282 - 1s/epoch - 4ms/step
# Epoch 17/1000
#
# Epoch 17: val_acc improved from 0.92817 to 0.93466, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.1993 - acc: 0.9205 - val_loss: 0.1778 - val_acc: 0.9347 - 1s/epoch - 4ms/step
# Epoch 18/1000
#
# Epoch 18: val_acc did not improve from 0.93466
# 308/308 - 1s - loss: 0.1926 - acc: 0.9218 - val_loss: 0.1862 - val_acc: 0.9253 - 1s/epoch - 4ms/step
# Epoch 19/1000
#
# Epoch 19: val_acc did not improve from 0.93466
# 308/308 - 1s - loss: 0.1975 - acc: 0.9195 - val_loss: 0.1818 - val_acc: 0.9298 - 1s/epoch - 3ms/step
# Epoch 20/1000
#
# Epoch 20: val_acc did not improve from 0.93466
# 308/308 - 1s - loss: 0.1918 - acc: 0.9248 - val_loss: 0.1958 - val_acc: 0.9213 - 1s/epoch - 4ms/step
# Epoch 21/1000
#
# Epoch 21: val_acc improved from 0.93466 to 0.93669, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.1860 - acc: 0.9250 - val_loss: 0.1733 - val_acc: 0.9367 - 1s/epoch - 4ms/step
# Epoch 22/1000
#
# Epoch 22: val_acc improved from 0.93669 to 0.93831, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.1783 - acc: 0.9269 - val_loss: 0.1679 - val_acc: 0.9383 - 1s/epoch - 4ms/step
# Epoch 23/1000
#
# Epoch 23: val_acc improved from 0.93831 to 0.94115, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.1815 - acc: 0.9286 - val_loss: 0.1795 - val_acc: 0.9412 - 1s/epoch - 4ms/step
# Epoch 24/1000
#
# Epoch 24: val_acc did not improve from 0.94115
# 308/308 - 1s - loss: 0.1774 - acc: 0.9273 - val_loss: 0.1713 - val_acc: 0.9343 - 1s/epoch - 4ms/step
# Epoch 25/1000
#
# Epoch 25: val_acc did not improve from 0.94115
# 308/308 - 2s - loss: 0.1717 - acc: 0.9335 - val_loss: 0.1873 - val_acc: 0.9363 - 2s/epoch - 5ms/step
# Epoch 26/1000
#
# Epoch 26: val_acc did not improve from 0.94115
# 308/308 - 2s - loss: 0.1722 - acc: 0.9282 - val_loss: 0.1734 - val_acc: 0.9367 - 2s/epoch - 6ms/step
# Epoch 27/1000
#
# Epoch 27: val_acc did not improve from 0.94115
# 308/308 - 1s - loss: 0.1667 - acc: 0.9311 - val_loss: 0.1689 - val_acc: 0.9379 - 1s/epoch - 5ms/step
# Epoch 28/1000
#
# Epoch 28: val_acc improved from 0.94115 to 0.94399, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.1643 - acc: 0.9334 - val_loss: 0.1718 - val_acc: 0.9440 - 1s/epoch - 5ms/step
# Epoch 29/1000
#
# Epoch 29: val_acc did not improve from 0.94399
# 308/308 - 1s - loss: 0.1647 - acc: 0.9311 - val_loss: 0.1653 - val_acc: 0.9412 - 1s/epoch - 4ms/step
# Epoch 30/1000
#
# Epoch 30: val_acc did not improve from 0.94399
# 308/308 - 1s - loss: 0.1585 - acc: 0.9378 - val_loss: 0.1785 - val_acc: 0.9318 - 1s/epoch - 4ms/step
# Epoch 31/1000
#
# Epoch 31: val_acc did not improve from 0.94399
# 308/308 - 2s - loss: 0.1669 - acc: 0.9328 - val_loss: 0.1806 - val_acc: 0.9338 - 2s/epoch - 5ms/step
# Epoch 32/1000
#
# Epoch 32: val_acc did not improve from 0.94399
# 308/308 - 1s - loss: 0.1587 - acc: 0.9368 - val_loss: 0.1746 - val_acc: 0.9367 - 1s/epoch - 4ms/step
# Epoch 33/1000
#
# Epoch 33: val_acc did not improve from 0.94399
# 308/308 - 1s - loss: 0.1550 - acc: 0.9368 - val_loss: 0.1839 - val_acc: 0.9395 - 1s/epoch - 4ms/step
# Epoch 34/1000
#
# Epoch 34: val_acc did not improve from 0.94399
# 308/308 - 1s - loss: 0.1437 - acc: 0.9418 - val_loss: 0.1881 - val_acc: 0.9387 - 1s/epoch - 4ms/step
# Epoch 35/1000
#
# Epoch 35: val_acc did not improve from 0.94399
# 308/308 - 1s - loss: 0.1527 - acc: 0.9387 - val_loss: 0.1730 - val_acc: 0.9436 - 1s/epoch - 5ms/step
# Epoch 36/1000
#
# Epoch 36: val_acc did not improve from 0.94399
# 308/308 - 1s - loss: 0.1501 - acc: 0.9396 - val_loss: 0.1676 - val_acc: 0.9403 - 1s/epoch - 4ms/step
# Epoch 37/1000
#
# Epoch 37: val_acc did not improve from 0.94399
# 308/308 - 1s - loss: 0.1440 - acc: 0.9428 - val_loss: 0.1633 - val_acc: 0.9432 - 1s/epoch - 4ms/step
# Epoch 38/1000
#
# Epoch 38: val_acc improved from 0.94399 to 0.94562, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.1481 - acc: 0.9431 - val_loss: 0.1730 - val_acc: 0.9456 - 1s/epoch - 5ms/step
# Epoch 39/1000
#
# Epoch 39: val_acc improved from 0.94562 to 0.95008, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.1425 - acc: 0.9451 - val_loss: 0.1579 - val_acc: 0.9501 - 1s/epoch - 5ms/step
# Epoch 40/1000
#
# Epoch 40: val_acc did not improve from 0.95008
# 308/308 - 1s - loss: 0.1425 - acc: 0.9422 - val_loss: 0.1731 - val_acc: 0.9436 - 1s/epoch - 4ms/step
# Epoch 41/1000
#
# Epoch 41: val_acc did not improve from 0.95008
# 308/308 - 1s - loss: 0.1419 - acc: 0.9458 - val_loss: 0.1672 - val_acc: 0.9448 - 1s/epoch - 4ms/step
# Epoch 42/1000
#
# Epoch 42: val_acc did not improve from 0.95008
# 308/308 - 1s - loss: 0.1442 - acc: 0.9438 - val_loss: 0.1747 - val_acc: 0.9416 - 1s/epoch - 4ms/step
# Epoch 43/1000
#
# Epoch 43: val_acc did not improve from 0.95008
# 308/308 - 2s - loss: 0.1417 - acc: 0.9428 - val_loss: 0.1754 - val_acc: 0.9464 - 2s/epoch - 5ms/step
# Epoch 44/1000
#
# Epoch 44: val_acc did not improve from 0.95008
# 308/308 - 1s - loss: 0.1464 - acc: 0.9416 - val_loss: 0.1785 - val_acc: 0.9468 - 1s/epoch - 4ms/step
# Epoch 45/1000
#
# Epoch 45: val_acc did not improve from 0.95008
# 308/308 - 1s - loss: 0.1339 - acc: 0.9466 - val_loss: 0.1780 - val_acc: 0.9468 - 1s/epoch - 4ms/step
# Epoch 46/1000
#
# Epoch 46: val_acc did not improve from 0.95008
# 308/308 - 1s - loss: 0.1278 - acc: 0.9494 - val_loss: 0.1711 - val_acc: 0.9472 - 1s/epoch - 5ms/step
# Epoch 47/1000
#
# Epoch 47: val_acc did not improve from 0.95008
# 308/308 - 1s - loss: 0.1350 - acc: 0.9454 - val_loss: 0.1788 - val_acc: 0.9452 - 1s/epoch - 4ms/step
# Epoch 48/1000
#
# Epoch 48: val_acc did not improve from 0.95008
# 308/308 - 1s - loss: 0.1289 - acc: 0.9467 - val_loss: 0.1765 - val_acc: 0.9432 - 1s/epoch - 4ms/step
# Epoch 49/1000
#
# Epoch 49: val_acc did not improve from 0.95008
# 308/308 - 1s - loss: 0.1320 - acc: 0.9480 - val_loss: 0.1805 - val_acc: 0.9444 - 1s/epoch - 4ms/step
# Epoch 50/1000
#
# Epoch 50: val_acc did not improve from 0.95008
# 308/308 - 2s - loss: 0.1338 - acc: 0.9494 - val_loss: 0.1779 - val_acc: 0.9485 - 2s/epoch - 5ms/step
# Epoch 51/1000
#
# Epoch 51: val_acc did not improve from 0.95008
# 308/308 - 2s - loss: 0.1351 - acc: 0.9467 - val_loss: 0.1704 - val_acc: 0.9489 - 2s/epoch - 5ms/step
# Epoch 52/1000
#
# Epoch 52: val_acc improved from 0.95008 to 0.95414, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 2s - loss: 0.1352 - acc: 0.9466 - val_loss: 0.1706 - val_acc: 0.9541 - 2s/epoch - 6ms/step
# Epoch 53/1000
#
# Epoch 53: val_acc did not improve from 0.95414
# 308/308 - 2s - loss: 0.1312 - acc: 0.9509 - val_loss: 0.1710 - val_acc: 0.9485 - 2s/epoch - 5ms/step
# Epoch 54/1000
#
# Epoch 54: val_acc did not improve from 0.95414
# 308/308 - 2s - loss: 0.1309 - acc: 0.9524 - val_loss: 0.1658 - val_acc: 0.9513 - 2s/epoch - 5ms/step
# Epoch 55/1000
#
# Epoch 55: val_acc improved from 0.95414 to 0.95495, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 2s - loss: 0.1259 - acc: 0.9498 - val_loss: 0.1680 - val_acc: 0.9550 - 2s/epoch - 6ms/step
# Epoch 56/1000
#
# Epoch 56: val_acc did not improve from 0.95495
# 308/308 - 1s - loss: 0.1256 - acc: 0.9506 - val_loss: 0.1749 - val_acc: 0.9485 - 1s/epoch - 4ms/step
# Epoch 57/1000
#
# Epoch 57: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1306 - acc: 0.9473 - val_loss: 0.1796 - val_acc: 0.9493 - 2s/epoch - 5ms/step
# Epoch 58/1000
#
# Epoch 58: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1257 - acc: 0.9511 - val_loss: 0.1750 - val_acc: 0.9472 - 2s/epoch - 5ms/step
# Epoch 59/1000
#
# Epoch 59: val_acc did not improve from 0.95495
# 308/308 - 1s - loss: 0.1219 - acc: 0.9506 - val_loss: 0.1854 - val_acc: 0.9456 - 1s/epoch - 4ms/step
# Epoch 60/1000
#
# Epoch 60: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1275 - acc: 0.9519 - val_loss: 0.1873 - val_acc: 0.9489 - 2s/epoch - 6ms/step
# Epoch 61/1000
#
# Epoch 61: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1220 - acc: 0.9515 - val_loss: 0.1820 - val_acc: 0.9448 - 2s/epoch - 6ms/step
# Epoch 62/1000
#
# Epoch 62: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1231 - acc: 0.9524 - val_loss: 0.1868 - val_acc: 0.9505 - 2s/epoch - 5ms/step
# Epoch 63/1000
#
# Epoch 63: val_acc did not improve from 0.95495
# 308/308 - 1s - loss: 0.1200 - acc: 0.9531 - val_loss: 0.1821 - val_acc: 0.9521 - 1s/epoch - 5ms/step
# Epoch 64/1000
#
# Epoch 64: val_acc did not improve from 0.95495
# 308/308 - 1s - loss: 0.1162 - acc: 0.9534 - val_loss: 0.1873 - val_acc: 0.9550 - 1s/epoch - 5ms/step
# Epoch 65/1000
#
# Epoch 65: val_acc did not improve from 0.95495
# 308/308 - 1s - loss: 0.1230 - acc: 0.9555 - val_loss: 0.1839 - val_acc: 0.9501 - 1s/epoch - 4ms/step
# Epoch 66/1000
#
# Epoch 66: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1189 - acc: 0.9541 - val_loss: 0.1871 - val_acc: 0.9460 - 2s/epoch - 5ms/step
# Epoch 67/1000
#
# Epoch 67: val_acc did not improve from 0.95495
# 308/308 - 1s - loss: 0.1248 - acc: 0.9520 - val_loss: 0.1820 - val_acc: 0.9452 - 1s/epoch - 5ms/step
# Epoch 68/1000
#
# Epoch 68: val_acc did not improve from 0.95495
# 308/308 - 1s - loss: 0.1175 - acc: 0.9528 - val_loss: 0.1800 - val_acc: 0.9525 - 1s/epoch - 4ms/step
# Epoch 69/1000
#
# Epoch 69: val_acc did not improve from 0.95495
# 308/308 - 1s - loss: 0.1126 - acc: 0.9556 - val_loss: 0.1832 - val_acc: 0.9533 - 1s/epoch - 4ms/step
# Epoch 70/1000
#
# Epoch 70: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1218 - acc: 0.9521 - val_loss: 0.1792 - val_acc: 0.9472 - 2s/epoch - 5ms/step
# Epoch 71/1000
#
# Epoch 71: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1173 - acc: 0.9570 - val_loss: 0.1696 - val_acc: 0.9521 - 2s/epoch - 5ms/step
# Epoch 72/1000
#
# Epoch 72: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1165 - acc: 0.9548 - val_loss: 0.1710 - val_acc: 0.9517 - 2s/epoch - 5ms/step
# Epoch 73/1000
#
# Epoch 73: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1120 - acc: 0.9571 - val_loss: 0.1850 - val_acc: 0.9509 - 2s/epoch - 6ms/step
# Epoch 74/1000
#
# Epoch 74: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1132 - acc: 0.9558 - val_loss: 0.1877 - val_acc: 0.9403 - 2s/epoch - 5ms/step
# Epoch 75/1000
#
# Epoch 75: val_acc did not improve from 0.95495
# 308/308 - 1s - loss: 0.1180 - acc: 0.9540 - val_loss: 0.1798 - val_acc: 0.9517 - 1s/epoch - 4ms/step
# Epoch 76/1000
#
# Epoch 76: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1185 - acc: 0.9547 - val_loss: 0.1739 - val_acc: 0.9505 - 2s/epoch - 5ms/step
# Epoch 77/1000
#
# Epoch 77: val_acc did not improve from 0.95495
# 308/308 - 1s - loss: 0.1138 - acc: 0.9559 - val_loss: 0.1857 - val_acc: 0.9497 - 1s/epoch - 5ms/step
# Epoch 78/1000
#
# Epoch 78: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1077 - acc: 0.9568 - val_loss: 0.1959 - val_acc: 0.9497 - 2s/epoch - 5ms/step
# Epoch 79/1000
#
# Epoch 79: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1058 - acc: 0.9568 - val_loss: 0.1883 - val_acc: 0.9489 - 2s/epoch - 5ms/step
# Epoch 80/1000
#
# Epoch 80: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1069 - acc: 0.9592 - val_loss: 0.1790 - val_acc: 0.9513 - 2s/epoch - 6ms/step
# Epoch 81/1000
#
# Epoch 81: val_acc did not improve from 0.95495
# 308/308 - 2s - loss: 0.1050 - acc: 0.9604 - val_loss: 0.1842 - val_acc: 0.9545 - 2s/epoch - 6ms/step
# Epoch 82/1000
#
# Epoch 82: val_acc improved from 0.95495 to 0.95576, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 2s - loss: 0.1140 - acc: 0.9546 - val_loss: 0.1772 - val_acc: 0.9558 - 2s/epoch - 6ms/step
# Epoch 83/1000
#
# Epoch 83: val_acc did not improve from 0.95576
# 308/308 - 2s - loss: 0.1069 - acc: 0.9602 - val_loss: 0.1875 - val_acc: 0.9554 - 2s/epoch - 5ms/step
# Epoch 84/1000
#
# Epoch 84: val_acc did not improve from 0.95576
# 308/308 - 1s - loss: 0.1124 - acc: 0.9551 - val_loss: 0.1810 - val_acc: 0.9529 - 1s/epoch - 5ms/step
# Epoch 85/1000
#
# Epoch 85: val_acc did not improve from 0.95576
# 308/308 - 2s - loss: 0.1084 - acc: 0.9581 - val_loss: 0.1985 - val_acc: 0.9460 - 2s/epoch - 5ms/step
# Epoch 86/1000
#
# Epoch 86: val_acc did not improve from 0.95576
# 308/308 - 1s - loss: 0.1050 - acc: 0.9597 - val_loss: 0.1817 - val_acc: 0.9525 - 1s/epoch - 5ms/step
# Epoch 87/1000
#
# Epoch 87: val_acc did not improve from 0.95576
# 308/308 - 2s - loss: 0.1115 - acc: 0.9581 - val_loss: 0.1863 - val_acc: 0.9550 - 2s/epoch - 5ms/step
# Epoch 88/1000
#
# Epoch 88: val_acc improved from 0.95576 to 0.95820, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.1045 - acc: 0.9594 - val_loss: 0.1847 - val_acc: 0.9582 - 1s/epoch - 5ms/step
# Epoch 89/1000
#
# Epoch 89: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1076 - acc: 0.9583 - val_loss: 0.1930 - val_acc: 0.9550 - 2s/epoch - 5ms/step
# Epoch 90/1000
#
# Epoch 90: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1084 - acc: 0.9594 - val_loss: 0.1924 - val_acc: 0.9554 - 2s/epoch - 5ms/step
# Epoch 91/1000
#
# Epoch 91: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1043 - acc: 0.9638 - val_loss: 0.1892 - val_acc: 0.9521 - 2s/epoch - 5ms/step
# Epoch 92/1000
#
# Epoch 92: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1023 - acc: 0.9594 - val_loss: 0.1969 - val_acc: 0.9521 - 2s/epoch - 6ms/step
# Epoch 93/1000
#
# Epoch 93: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.1063 - acc: 0.9575 - val_loss: 0.1931 - val_acc: 0.9582 - 1s/epoch - 4ms/step
# Epoch 94/1000
#
# Epoch 94: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.1047 - acc: 0.9598 - val_loss: 0.1831 - val_acc: 0.9582 - 1s/epoch - 4ms/step
# Epoch 95/1000
#
# Epoch 95: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.1005 - acc: 0.9626 - val_loss: 0.1960 - val_acc: 0.9537 - 1s/epoch - 4ms/step
# Epoch 96/1000
#
# Epoch 96: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.0995 - acc: 0.9613 - val_loss: 0.1951 - val_acc: 0.9570 - 1s/epoch - 4ms/step
# Epoch 97/1000
#
# Epoch 97: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.0952 - acc: 0.9628 - val_loss: 0.2104 - val_acc: 0.9497 - 1s/epoch - 4ms/step
# Epoch 98/1000
#
# Epoch 98: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.1040 - acc: 0.9614 - val_loss: 0.1981 - val_acc: 0.9537 - 1s/epoch - 4ms/step
# Epoch 99/1000
#
# Epoch 99: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.0963 - acc: 0.9624 - val_loss: 0.1976 - val_acc: 0.9537 - 1s/epoch - 4ms/step
# Epoch 100/1000
#
# Epoch 100: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.0992 - acc: 0.9619 - val_loss: 0.1883 - val_acc: 0.9574 - 1s/epoch - 4ms/step
# Epoch 101/1000
#
# Epoch 101: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.0960 - acc: 0.9629 - val_loss: 0.2074 - val_acc: 0.9505 - 1s/epoch - 4ms/step
# Epoch 102/1000
#
# Epoch 102: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.0974 - acc: 0.9633 - val_loss: 0.2086 - val_acc: 0.9541 - 1s/epoch - 5ms/step
# Epoch 103/1000
#
# Epoch 103: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.0967 - acc: 0.9651 - val_loss: 0.2114 - val_acc: 0.9493 - 2s/epoch - 5ms/step
# Epoch 104/1000
#
# Epoch 104: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1027 - acc: 0.9614 - val_loss: 0.1894 - val_acc: 0.9521 - 2s/epoch - 5ms/step
# Epoch 105/1000
#
# Epoch 105: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1017 - acc: 0.9603 - val_loss: 0.1851 - val_acc: 0.9497 - 2s/epoch - 5ms/step
# Epoch 106/1000
#
# Epoch 106: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1016 - acc: 0.9599 - val_loss: 0.1925 - val_acc: 0.9529 - 2s/epoch - 5ms/step
# Epoch 107/1000
#
# Epoch 107: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1021 - acc: 0.9626 - val_loss: 0.2026 - val_acc: 0.9505 - 2s/epoch - 6ms/step
# Epoch 108/1000
#
# Epoch 108: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.0986 - acc: 0.9603 - val_loss: 0.2064 - val_acc: 0.9562 - 2s/epoch - 7ms/step
# Epoch 109/1000
#
# Epoch 109: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1010 - acc: 0.9611 - val_loss: 0.2021 - val_acc: 0.9513 - 2s/epoch - 6ms/step
# Epoch 110/1000
#
# Epoch 110: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1008 - acc: 0.9629 - val_loss: 0.1928 - val_acc: 0.9562 - 2s/epoch - 6ms/step
# Epoch 111/1000
#
# Epoch 111: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.0985 - acc: 0.9638 - val_loss: 0.1916 - val_acc: 0.9558 - 2s/epoch - 6ms/step
# Epoch 112/1000
#
# Epoch 112: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.1032 - acc: 0.9605 - val_loss: 0.1751 - val_acc: 0.9489 - 2s/epoch - 5ms/step
# Epoch 113/1000
#
# Epoch 113: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.0984 - acc: 0.9626 - val_loss: 0.1645 - val_acc: 0.9554 - 1s/epoch - 5ms/step
# Epoch 114/1000
#
# Epoch 114: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.0888 - acc: 0.9679 - val_loss: 0.1789 - val_acc: 0.9541 - 2s/epoch - 5ms/step
# Epoch 115/1000
#
# Epoch 115: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.0966 - acc: 0.9619 - val_loss: 0.1832 - val_acc: 0.9574 - 2s/epoch - 6ms/step
# Epoch 116/1000
#
# Epoch 116: val_acc did not improve from 0.95820
# 308/308 - 1s - loss: 0.0929 - acc: 0.9657 - val_loss: 0.1840 - val_acc: 0.9558 - 1s/epoch - 5ms/step
# Epoch 117/1000
#
# Epoch 117: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.0974 - acc: 0.9631 - val_loss: 0.1856 - val_acc: 0.9517 - 2s/epoch - 5ms/step
# Epoch 118/1000
#
# Epoch 118: val_acc did not improve from 0.95820
# 308/308 - 2s - loss: 0.0926 - acc: 0.9637 - val_loss: 0.1957 - val_acc: 0.9533 - 2s/epoch - 5ms/step
# Epoch 119/1000
#
# Epoch 119: val_acc improved from 0.95820 to 0.95982, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 2s - loss: 0.0962 - acc: 0.9637 - val_loss: 0.1935 - val_acc: 0.9598 - 2s/epoch - 5ms/step
# Epoch 120/1000
#
# Epoch 120: val_acc did not improve from 0.95982
# 308/308 - 2s - loss: 0.0964 - acc: 0.9644 - val_loss: 0.1997 - val_acc: 0.9578 - 2s/epoch - 5ms/step
# Epoch 121/1000
#
# Epoch 121: val_acc did not improve from 0.95982
# 308/308 - 1s - loss: 0.0946 - acc: 0.9643 - val_loss: 0.2018 - val_acc: 0.9554 - 1s/epoch - 5ms/step
# Epoch 122/1000
#
# Epoch 122: val_acc did not improve from 0.95982
# 308/308 - 2s - loss: 0.0978 - acc: 0.9632 - val_loss: 0.1950 - val_acc: 0.9566 - 2s/epoch - 6ms/step
# Epoch 123/1000
#
# Epoch 123: val_acc did not improve from 0.95982
# 308/308 - 2s - loss: 0.0948 - acc: 0.9625 - val_loss: 0.1955 - val_acc: 0.9570 - 2s/epoch - 5ms/step
# Epoch 124/1000
#
# Epoch 124: val_acc did not improve from 0.95982
# 308/308 - 2s - loss: 0.0934 - acc: 0.9657 - val_loss: 0.2052 - val_acc: 0.9517 - 2s/epoch - 6ms/step
# Epoch 125/1000
#
# Epoch 125: val_acc did not improve from 0.95982
# 308/308 - 2s - loss: 0.0877 - acc: 0.9657 - val_loss: 0.2162 - val_acc: 0.9505 - 2s/epoch - 7ms/step
# Epoch 126/1000
#
# Epoch 126: val_acc improved from 0.95982 to 0.96023, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 2s - loss: 0.0927 - acc: 0.9657 - val_loss: 0.1965 - val_acc: 0.9602 - 2s/epoch - 6ms/step
# Epoch 127/1000
#
# Epoch 127: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0961 - acc: 0.9649 - val_loss: 0.2012 - val_acc: 0.9570 - 2s/epoch - 5ms/step
# Epoch 128/1000
#
# Epoch 128: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0888 - acc: 0.9659 - val_loss: 0.2075 - val_acc: 0.9554 - 2s/epoch - 5ms/step
# Epoch 129/1000
#
# Epoch 129: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0921 - acc: 0.9663 - val_loss: 0.2006 - val_acc: 0.9570 - 2s/epoch - 5ms/step
# Epoch 130/1000
#
# Epoch 130: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0865 - acc: 0.9652 - val_loss: 0.2040 - val_acc: 0.9566 - 2s/epoch - 6ms/step
# Epoch 131/1000
#
# Epoch 131: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0927 - acc: 0.9654 - val_loss: 0.2078 - val_acc: 0.9582 - 2s/epoch - 5ms/step
# Epoch 132/1000
#
# Epoch 132: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0902 - acc: 0.9666 - val_loss: 0.1909 - val_acc: 0.9594 - 2s/epoch - 5ms/step
# Epoch 133/1000
#
# Epoch 133: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0888 - acc: 0.9661 - val_loss: 0.2062 - val_acc: 0.9554 - 2s/epoch - 5ms/step
# Epoch 134/1000
#
# Epoch 134: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0931 - acc: 0.9652 - val_loss: 0.2046 - val_acc: 0.9566 - 2s/epoch - 6ms/step
# Epoch 135/1000
#
# Epoch 135: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0863 - acc: 0.9672 - val_loss: 0.2265 - val_acc: 0.9489 - 2s/epoch - 5ms/step
# Epoch 136/1000
#
# Epoch 136: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0889 - acc: 0.9689 - val_loss: 0.2150 - val_acc: 0.9562 - 2s/epoch - 5ms/step
# Epoch 137/1000
#
# Epoch 137: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0956 - acc: 0.9654 - val_loss: 0.2185 - val_acc: 0.9554 - 1s/epoch - 4ms/step
# Epoch 138/1000
#
# Epoch 138: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0903 - acc: 0.9666 - val_loss: 0.2134 - val_acc: 0.9537 - 2s/epoch - 5ms/step
# Epoch 139/1000
#
# Epoch 139: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0807 - acc: 0.9669 - val_loss: 0.2222 - val_acc: 0.9545 - 1s/epoch - 5ms/step
# Epoch 140/1000
#
# Epoch 140: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0927 - acc: 0.9663 - val_loss: 0.2116 - val_acc: 0.9545 - 1s/epoch - 4ms/step
# Epoch 141/1000
#
# Epoch 141: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0896 - acc: 0.9652 - val_loss: 0.2192 - val_acc: 0.9550 - 2s/epoch - 5ms/step
# Epoch 142/1000
#
# Epoch 142: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0851 - acc: 0.9672 - val_loss: 0.2236 - val_acc: 0.9550 - 1s/epoch - 4ms/step
# Epoch 143/1000
#
# Epoch 143: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0881 - acc: 0.9679 - val_loss: 0.2179 - val_acc: 0.9558 - 1s/epoch - 5ms/step
# Epoch 144/1000
#
# Epoch 144: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0861 - acc: 0.9680 - val_loss: 0.2209 - val_acc: 0.9562 - 2s/epoch - 6ms/step
# Epoch 145/1000
#
# Epoch 145: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0852 - acc: 0.9685 - val_loss: 0.2137 - val_acc: 0.9562 - 1s/epoch - 5ms/step
# Epoch 146/1000
#
# Epoch 146: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0855 - acc: 0.9678 - val_loss: 0.2214 - val_acc: 0.9517 - 1s/epoch - 5ms/step
# Epoch 147/1000
#
# Epoch 147: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0850 - acc: 0.9692 - val_loss: 0.2321 - val_acc: 0.9562 - 2s/epoch - 6ms/step
# Epoch 148/1000
#
# Epoch 148: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0852 - acc: 0.9680 - val_loss: 0.2221 - val_acc: 0.9521 - 1s/epoch - 5ms/step
# Epoch 149/1000
#
# Epoch 149: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0909 - acc: 0.9659 - val_loss: 0.2108 - val_acc: 0.9537 - 1s/epoch - 4ms/step
# Epoch 150/1000
#
# Epoch 150: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0866 - acc: 0.9672 - val_loss: 0.2161 - val_acc: 0.9533 - 1s/epoch - 4ms/step
# Epoch 151/1000
#
# Epoch 151: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0936 - acc: 0.9674 - val_loss: 0.2116 - val_acc: 0.9558 - 1s/epoch - 4ms/step
# Epoch 152/1000
#
# Epoch 152: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0850 - acc: 0.9676 - val_loss: 0.2120 - val_acc: 0.9566 - 1s/epoch - 5ms/step
# Epoch 153/1000
#
# Epoch 153: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0848 - acc: 0.9699 - val_loss: 0.2175 - val_acc: 0.9541 - 1s/epoch - 4ms/step
# Epoch 154/1000
#
# Epoch 154: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0869 - acc: 0.9670 - val_loss: 0.2183 - val_acc: 0.9533 - 2s/epoch - 5ms/step
# Epoch 155/1000
#
# Epoch 155: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0818 - acc: 0.9694 - val_loss: 0.2240 - val_acc: 0.9566 - 1s/epoch - 5ms/step
# Epoch 156/1000
#
# Epoch 156: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0852 - acc: 0.9692 - val_loss: 0.2350 - val_acc: 0.9517 - 1s/epoch - 5ms/step
# Epoch 157/1000
#
# Epoch 157: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0823 - acc: 0.9678 - val_loss: 0.2279 - val_acc: 0.9529 - 1s/epoch - 4ms/step
# Epoch 158/1000
#
# Epoch 158: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0858 - acc: 0.9683 - val_loss: 0.2209 - val_acc: 0.9574 - 2s/epoch - 5ms/step
# Epoch 159/1000
#
# Epoch 159: val_acc did not improve from 0.96023
# 308/308 - 1s - loss: 0.0836 - acc: 0.9687 - val_loss: 0.2227 - val_acc: 0.9566 - 1s/epoch - 5ms/step
# Epoch 160/1000
#
# Epoch 160: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0829 - acc: 0.9684 - val_loss: 0.2134 - val_acc: 0.9541 - 2s/epoch - 5ms/step
# Epoch 161/1000
#
# Epoch 161: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0845 - acc: 0.9679 - val_loss: 0.2177 - val_acc: 0.9594 - 2s/epoch - 6ms/step
# Epoch 162/1000
#
# Epoch 162: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0841 - acc: 0.9698 - val_loss: 0.2097 - val_acc: 0.9570 - 2s/epoch - 5ms/step
# Epoch 163/1000
#
# Epoch 163: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0854 - acc: 0.9681 - val_loss: 0.2191 - val_acc: 0.9582 - 2s/epoch - 7ms/step
# Epoch 164/1000
#
# Epoch 164: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0839 - acc: 0.9684 - val_loss: 0.2328 - val_acc: 0.9598 - 2s/epoch - 6ms/step
# Epoch 165/1000
#
# Epoch 165: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0783 - acc: 0.9707 - val_loss: 0.2130 - val_acc: 0.9570 - 2s/epoch - 6ms/step
# Epoch 166/1000
#
# Epoch 166: val_acc did not improve from 0.96023
# 308/308 - 2s - loss: 0.0769 - acc: 0.9714 - val_loss: 0.2151 - val_acc: 0.9582 - 2s/epoch - 8ms/step
# Epoch 167/1000
#
# Epoch 167: val_acc improved from 0.96023 to 0.96063, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.0873 - acc: 0.9664 - val_loss: 0.2123 - val_acc: 0.9606 - 1s/epoch - 5ms/step
# Epoch 168/1000
#
# Epoch 168: val_acc did not improve from 0.96063
# 308/308 - 1s - loss: 0.0794 - acc: 0.9703 - val_loss: 0.2221 - val_acc: 0.9545 - 1s/epoch - 4ms/step
# Epoch 169/1000
#
# Epoch 169: val_acc did not improve from 0.96063
# 308/308 - 2s - loss: 0.0801 - acc: 0.9707 - val_loss: 0.2181 - val_acc: 0.9566 - 2s/epoch - 5ms/step
# Epoch 170/1000
#
# Epoch 170: val_acc did not improve from 0.96063
# 308/308 - 2s - loss: 0.0721 - acc: 0.9716 - val_loss: 0.2156 - val_acc: 0.9590 - 2s/epoch - 6ms/step
# Epoch 171/1000
#
# Epoch 171: val_acc did not improve from 0.96063
# 308/308 - 1s - loss: 0.0795 - acc: 0.9713 - val_loss: 0.2178 - val_acc: 0.9578 - 1s/epoch - 5ms/step
# Epoch 172/1000
#
# Epoch 172: val_acc did not improve from 0.96063
# 308/308 - 1s - loss: 0.0783 - acc: 0.9703 - val_loss: 0.2211 - val_acc: 0.9550 - 1s/epoch - 5ms/step
# Epoch 173/1000
#
# Epoch 173: val_acc did not improve from 0.96063
# 308/308 - 2s - loss: 0.0833 - acc: 0.9691 - val_loss: 0.2042 - val_acc: 0.9562 - 2s/epoch - 5ms/step
# Epoch 174/1000
#
# Epoch 174: val_acc did not improve from 0.96063
# 308/308 - 1s - loss: 0.0817 - acc: 0.9703 - val_loss: 0.2010 - val_acc: 0.9594 - 1s/epoch - 5ms/step
# Epoch 175/1000
#
# Epoch 175: val_acc did not improve from 0.96063
# 308/308 - 2s - loss: 0.0759 - acc: 0.9704 - val_loss: 0.2170 - val_acc: 0.9574 - 2s/epoch - 6ms/step
# Epoch 176/1000
#
# Epoch 176: val_acc improved from 0.96063 to 0.96104, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 2s - loss: 0.0825 - acc: 0.9698 - val_loss: 0.2201 - val_acc: 0.9610 - 2s/epoch - 6ms/step
# Epoch 177/1000
#
# Epoch 177: val_acc did not improve from 0.96104
# 308/308 - 1s - loss: 0.0849 - acc: 0.9681 - val_loss: 0.2026 - val_acc: 0.9554 - 1s/epoch - 5ms/step
# Epoch 178/1000
#
# Epoch 178: val_acc did not improve from 0.96104
# 308/308 - 1s - loss: 0.0867 - acc: 0.9696 - val_loss: 0.2052 - val_acc: 0.9545 - 1s/epoch - 4ms/step
# Epoch 179/1000
#
# Epoch 179: val_acc did not improve from 0.96104
# 308/308 - 1s - loss: 0.0746 - acc: 0.9714 - val_loss: 0.2039 - val_acc: 0.9566 - 1s/epoch - 4ms/step
# Epoch 180/1000
#
# Epoch 180: val_acc did not improve from 0.96104
# 308/308 - 1s - loss: 0.0864 - acc: 0.9687 - val_loss: 0.2141 - val_acc: 0.9590 - 1s/epoch - 5ms/step
# Epoch 181/1000
#
# Epoch 181: val_acc did not improve from 0.96104
# 308/308 - 1s - loss: 0.0787 - acc: 0.9706 - val_loss: 0.2127 - val_acc: 0.9594 - 1s/epoch - 5ms/step
# Epoch 182/1000
#
# Epoch 182: val_acc did not improve from 0.96104
# 308/308 - 2s - loss: 0.0829 - acc: 0.9703 - val_loss: 0.2053 - val_acc: 0.9602 - 2s/epoch - 6ms/step
# Epoch 183/1000
#
# Epoch 183: val_acc improved from 0.96104 to 0.96144, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.0769 - acc: 0.9696 - val_loss: 0.1810 - val_acc: 0.9614 - 1s/epoch - 4ms/step
# Epoch 184/1000
#
# Epoch 184: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0793 - acc: 0.9714 - val_loss: 0.2020 - val_acc: 0.9610 - 1s/epoch - 4ms/step
# Epoch 185/1000
#
# Epoch 185: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0751 - acc: 0.9715 - val_loss: 0.2081 - val_acc: 0.9602 - 1s/epoch - 5ms/step
# Epoch 186/1000
#
# Epoch 186: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0721 - acc: 0.9745 - val_loss: 0.2253 - val_acc: 0.9590 - 1s/epoch - 4ms/step
# Epoch 187/1000
#
# Epoch 187: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0778 - acc: 0.9712 - val_loss: 0.2206 - val_acc: 0.9570 - 1s/epoch - 4ms/step
# Epoch 188/1000
#
# Epoch 188: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0717 - acc: 0.9726 - val_loss: 0.2201 - val_acc: 0.9570 - 1s/epoch - 5ms/step
# Epoch 189/1000
#
# Epoch 189: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0803 - acc: 0.9705 - val_loss: 0.2140 - val_acc: 0.9594 - 1s/epoch - 4ms/step
# Epoch 190/1000
#
# Epoch 190: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0747 - acc: 0.9703 - val_loss: 0.2200 - val_acc: 0.9574 - 1s/epoch - 5ms/step
# Epoch 191/1000
#
# Epoch 191: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0787 - acc: 0.9695 - val_loss: 0.2189 - val_acc: 0.9562 - 1s/epoch - 4ms/step
# Epoch 192/1000
#
# Epoch 192: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0724 - acc: 0.9757 - val_loss: 0.2296 - val_acc: 0.9497 - 1s/epoch - 4ms/step
# Epoch 193/1000
#
# Epoch 193: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0816 - acc: 0.9702 - val_loss: 0.2154 - val_acc: 0.9602 - 2s/epoch - 6ms/step
# Epoch 194/1000
#
# Epoch 194: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0750 - acc: 0.9733 - val_loss: 0.2245 - val_acc: 0.9558 - 1s/epoch - 4ms/step
# Epoch 195/1000
#
# Epoch 195: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0723 - acc: 0.9725 - val_loss: 0.2281 - val_acc: 0.9554 - 1s/epoch - 4ms/step
# Epoch 196/1000
#
# Epoch 196: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0709 - acc: 0.9738 - val_loss: 0.2265 - val_acc: 0.9570 - 1s/epoch - 4ms/step
# Epoch 197/1000
#
# Epoch 197: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0721 - acc: 0.9744 - val_loss: 0.2316 - val_acc: 0.9602 - 1s/epoch - 4ms/step
# Epoch 198/1000
#
# Epoch 198: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0754 - acc: 0.9716 - val_loss: 0.2276 - val_acc: 0.9550 - 1s/epoch - 5ms/step
# Epoch 199/1000
#
# Epoch 199: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0723 - acc: 0.9727 - val_loss: 0.2282 - val_acc: 0.9566 - 1s/epoch - 4ms/step
# Epoch 200/1000
#
# Epoch 200: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0773 - acc: 0.9715 - val_loss: 0.2261 - val_acc: 0.9582 - 2s/epoch - 6ms/step
# Epoch 201/1000
#
# Epoch 201: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0808 - acc: 0.9719 - val_loss: 0.2103 - val_acc: 0.9566 - 2s/epoch - 5ms/step
# Epoch 202/1000
#
# Epoch 202: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0755 - acc: 0.9730 - val_loss: 0.2356 - val_acc: 0.9574 - 1s/epoch - 4ms/step
# Epoch 203/1000
#
# Epoch 203: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0709 - acc: 0.9732 - val_loss: 0.2285 - val_acc: 0.9562 - 2s/epoch - 7ms/step
# Epoch 204/1000
#
# Epoch 204: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0699 - acc: 0.9730 - val_loss: 0.2461 - val_acc: 0.9554 - 1s/epoch - 5ms/step
# Epoch 205/1000
#
# Epoch 205: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0749 - acc: 0.9733 - val_loss: 0.2329 - val_acc: 0.9582 - 2s/epoch - 6ms/step
# Epoch 206/1000
#
# Epoch 206: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0745 - acc: 0.9714 - val_loss: 0.2269 - val_acc: 0.9598 - 2s/epoch - 5ms/step
# Epoch 207/1000
#
# Epoch 207: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0824 - acc: 0.9731 - val_loss: 0.2169 - val_acc: 0.9590 - 1s/epoch - 4ms/step
# Epoch 208/1000
#
# Epoch 208: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0723 - acc: 0.9711 - val_loss: 0.2433 - val_acc: 0.9558 - 2s/epoch - 6ms/step
# Epoch 209/1000
#
# Epoch 209: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0690 - acc: 0.9739 - val_loss: 0.2383 - val_acc: 0.9594 - 1s/epoch - 4ms/step
# Epoch 210/1000
#
# Epoch 210: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0758 - acc: 0.9718 - val_loss: 0.2221 - val_acc: 0.9582 - 1s/epoch - 4ms/step
# Epoch 211/1000
#
# Epoch 211: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0765 - acc: 0.9713 - val_loss: 0.2122 - val_acc: 0.9586 - 1s/epoch - 4ms/step
# Epoch 212/1000
#
# Epoch 212: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0680 - acc: 0.9740 - val_loss: 0.2259 - val_acc: 0.9606 - 2s/epoch - 5ms/step
# Epoch 213/1000
#
# Epoch 213: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0737 - acc: 0.9714 - val_loss: 0.2477 - val_acc: 0.9586 - 2s/epoch - 6ms/step
# Epoch 214/1000
#
# Epoch 214: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0710 - acc: 0.9737 - val_loss: 0.2371 - val_acc: 0.9566 - 1s/epoch - 4ms/step
# Epoch 215/1000
#
# Epoch 215: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0748 - acc: 0.9731 - val_loss: 0.2312 - val_acc: 0.9614 - 2s/epoch - 5ms/step
# Epoch 216/1000
#
# Epoch 216: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0751 - acc: 0.9700 - val_loss: 0.2348 - val_acc: 0.9566 - 1s/epoch - 5ms/step
# Epoch 217/1000
#
# Epoch 217: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0660 - acc: 0.9770 - val_loss: 0.2356 - val_acc: 0.9586 - 1s/epoch - 5ms/step
# Epoch 218/1000
#
# Epoch 218: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0742 - acc: 0.9732 - val_loss: 0.2277 - val_acc: 0.9590 - 2s/epoch - 5ms/step
# Epoch 219/1000
#
# Epoch 219: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0688 - acc: 0.9737 - val_loss: 0.2228 - val_acc: 0.9558 - 2s/epoch - 5ms/step
# Epoch 220/1000
#
# Epoch 220: val_acc did not improve from 0.96144
# 308/308 - 2s - loss: 0.0727 - acc: 0.9740 - val_loss: 0.2371 - val_acc: 0.9586 - 2s/epoch - 6ms/step
# Epoch 221/1000
#
# Epoch 221: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0687 - acc: 0.9744 - val_loss: 0.2472 - val_acc: 0.9554 - 1s/epoch - 5ms/step
# Epoch 222/1000
#
# Epoch 222: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0775 - acc: 0.9712 - val_loss: 0.2350 - val_acc: 0.9578 - 1s/epoch - 5ms/step
# Epoch 223/1000
#
# Epoch 223: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0670 - acc: 0.9754 - val_loss: 0.2449 - val_acc: 0.9606 - 1s/epoch - 4ms/step
# Epoch 224/1000
#
# Epoch 224: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0742 - acc: 0.9716 - val_loss: 0.2190 - val_acc: 0.9513 - 1s/epoch - 4ms/step
# Epoch 225/1000
#
# Epoch 225: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0688 - acc: 0.9736 - val_loss: 0.2318 - val_acc: 0.9614 - 1s/epoch - 4ms/step
# Epoch 226/1000
#
# Epoch 226: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0659 - acc: 0.9748 - val_loss: 0.2424 - val_acc: 0.9598 - 1s/epoch - 4ms/step
# Epoch 227/1000
#
# Epoch 227: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0746 - acc: 0.9733 - val_loss: 0.2253 - val_acc: 0.9574 - 1s/epoch - 5ms/step
# Epoch 228/1000
#
# Epoch 228: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0652 - acc: 0.9769 - val_loss: 0.2393 - val_acc: 0.9562 - 1s/epoch - 4ms/step
# Epoch 229/1000
#
# Epoch 229: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0785 - acc: 0.9711 - val_loss: 0.2256 - val_acc: 0.9570 - 1s/epoch - 4ms/step
# Epoch 230/1000
#
# Epoch 230: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0649 - acc: 0.9747 - val_loss: 0.2381 - val_acc: 0.9582 - 1s/epoch - 5ms/step
# Epoch 231/1000
#
# Epoch 231: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0709 - acc: 0.9738 - val_loss: 0.2419 - val_acc: 0.9614 - 1s/epoch - 5ms/step
# Epoch 232/1000
#
# Epoch 232: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0734 - acc: 0.9731 - val_loss: 0.2436 - val_acc: 0.9606 - 1s/epoch - 4ms/step
# Epoch 233/1000
#
# Epoch 233: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0681 - acc: 0.9734 - val_loss: 0.2340 - val_acc: 0.9558 - 1s/epoch - 4ms/step
# Epoch 234/1000
#
# Epoch 234: val_acc did not improve from 0.96144
# 308/308 - 1s - loss: 0.0704 - acc: 0.9753 - val_loss: 0.2347 - val_acc: 0.9598 - 1s/epoch - 4ms/step
# Epoch 235/1000
#
# Epoch 235: val_acc improved from 0.96144 to 0.96185, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 2s - loss: 0.0655 - acc: 0.9765 - val_loss: 0.2537 - val_acc: 0.9619 - 2s/epoch - 5ms/step
# Epoch 236/1000
#
# Epoch 236: val_acc did not improve from 0.96185
# 308/308 - 1s - loss: 0.0759 - acc: 0.9722 - val_loss: 0.2417 - val_acc: 0.9594 - 1s/epoch - 4ms/step
# Epoch 237/1000
#
# Epoch 237: val_acc did not improve from 0.96185
# 308/308 - 1s - loss: 0.0657 - acc: 0.9742 - val_loss: 0.2096 - val_acc: 0.9586 - 1s/epoch - 4ms/step
# Epoch 238/1000
#
# Epoch 238: val_acc did not improve from 0.96185
# 308/308 - 1s - loss: 0.0678 - acc: 0.9767 - val_loss: 0.2184 - val_acc: 0.9614 - 1s/epoch - 4ms/step
# Epoch 239/1000
#
# Epoch 239: val_acc did not improve from 0.96185
# 308/308 - 1s - loss: 0.0728 - acc: 0.9755 - val_loss: 0.2227 - val_acc: 0.9594 - 1s/epoch - 4ms/step
# Epoch 240/1000
#
# Epoch 240: val_acc improved from 0.96185 to 0.96307, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.0670 - acc: 0.9754 - val_loss: 0.2292 - val_acc: 0.9631 - 1s/epoch - 5ms/step
# Epoch 241/1000
#
# Epoch 241: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0684 - acc: 0.9728 - val_loss: 0.2365 - val_acc: 0.9619 - 1s/epoch - 4ms/step
# Epoch 242/1000
#
# Epoch 242: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0663 - acc: 0.9761 - val_loss: 0.2484 - val_acc: 0.9566 - 1s/epoch - 4ms/step
# Epoch 243/1000
#
# Epoch 243: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0685 - acc: 0.9740 - val_loss: 0.2493 - val_acc: 0.9574 - 1s/epoch - 4ms/step
# Epoch 244/1000
#
# Epoch 244: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0743 - acc: 0.9734 - val_loss: 0.2407 - val_acc: 0.9578 - 1s/epoch - 4ms/step
# Epoch 245/1000
#
# Epoch 245: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0716 - acc: 0.9747 - val_loss: 0.2371 - val_acc: 0.9550 - 1s/epoch - 5ms/step
# Epoch 246/1000
#
# Epoch 246: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0682 - acc: 0.9741 - val_loss: 0.2478 - val_acc: 0.9598 - 1s/epoch - 4ms/step
# Epoch 247/1000
#
# Epoch 247: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0682 - acc: 0.9725 - val_loss: 0.2141 - val_acc: 0.9574 - 1s/epoch - 4ms/step
# Epoch 248/1000
#
# Epoch 248: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0700 - acc: 0.9754 - val_loss: 0.2293 - val_acc: 0.9582 - 1s/epoch - 4ms/step
# Epoch 249/1000
#
# Epoch 249: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0653 - acc: 0.9766 - val_loss: 0.2318 - val_acc: 0.9606 - 1s/epoch - 4ms/step
# Epoch 250/1000
#
# Epoch 250: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0659 - acc: 0.9756 - val_loss: 0.2410 - val_acc: 0.9578 - 1s/epoch - 4ms/step
# Epoch 251/1000
#
# Epoch 251: val_acc did not improve from 0.96307
# 308/308 - 2s - loss: 0.0641 - acc: 0.9770 - val_loss: 0.2350 - val_acc: 0.9586 - 2s/epoch - 5ms/step
# Epoch 252/1000
#
# Epoch 252: val_acc did not improve from 0.96307
# 308/308 - 2s - loss: 0.0657 - acc: 0.9755 - val_loss: 0.2454 - val_acc: 0.9574 - 2s/epoch - 5ms/step
# Epoch 253/1000
#
# Epoch 253: val_acc did not improve from 0.96307
# 308/308 - 1s - loss: 0.0666 - acc: 0.9748 - val_loss: 0.2585 - val_acc: 0.9594 - 1s/epoch - 5ms/step
# Epoch 254/1000
#
# Epoch 254: val_acc improved from 0.96307 to 0.96347, saving model to train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_512_256_Adam\1\256\best_model.h5
# 308/308 - 1s - loss: 0.0705 - acc: 0.9750 - val_loss: 0.2452 - val_acc: 0.9635 - 1s/epoch - 4ms/step
# Epoch 255/1000
#
# Epoch 255: val_acc did not improve from 0.96347
# 308/308 - 2s - loss: 0.0695 - acc: 0.9739 - val_loss: 0.2191 - val_acc: 0.9623 - 2s/epoch - 5ms/step
# Epoch 256/1000
#
# Epoch 256: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0651 - acc: 0.9766 - val_loss: 0.2562 - val_acc: 0.9614 - 1s/epoch - 4ms/step
# Epoch 257/1000
#
# Epoch 257: val_acc did not improve from 0.96347
# 308/308 - 2s - loss: 0.0674 - acc: 0.9755 - val_loss: 0.2589 - val_acc: 0.9602 - 2s/epoch - 6ms/step
# Epoch 258/1000
#
# Epoch 258: val_acc did not improve from 0.96347
# 308/308 - 2s - loss: 0.0680 - acc: 0.9768 - val_loss: 0.2299 - val_acc: 0.9614 - 2s/epoch - 5ms/step
# Epoch 259/1000
#
# Epoch 259: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0714 - acc: 0.9768 - val_loss: 0.2447 - val_acc: 0.9574 - 1s/epoch - 5ms/step
# Epoch 260/1000
#
# Epoch 260: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0687 - acc: 0.9758 - val_loss: 0.2508 - val_acc: 0.9594 - 1s/epoch - 5ms/step
# Epoch 261/1000
#
# Epoch 261: val_acc did not improve from 0.96347
# 308/308 - 2s - loss: 0.0705 - acc: 0.9742 - val_loss: 0.2440 - val_acc: 0.9566 - 2s/epoch - 5ms/step
# Epoch 262/1000
#
# Epoch 262: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0708 - acc: 0.9755 - val_loss: 0.2343 - val_acc: 0.9602 - 1s/epoch - 4ms/step
# Epoch 263/1000
#
# Epoch 263: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0697 - acc: 0.9750 - val_loss: 0.2134 - val_acc: 0.9631 - 1s/epoch - 5ms/step
# Epoch 264/1000
#
# Epoch 264: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0724 - acc: 0.9764 - val_loss: 0.2106 - val_acc: 0.9598 - 1s/epoch - 4ms/step
# Epoch 265/1000
#
# Epoch 265: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0651 - acc: 0.9783 - val_loss: 0.2243 - val_acc: 0.9578 - 1s/epoch - 4ms/step
# Epoch 266/1000
#
# Epoch 266: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0725 - acc: 0.9746 - val_loss: 0.2183 - val_acc: 0.9610 - 1s/epoch - 5ms/step
# Epoch 267/1000
#
# Epoch 267: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0717 - acc: 0.9756 - val_loss: 0.2295 - val_acc: 0.9606 - 1s/epoch - 5ms/step
# Epoch 268/1000
#
# Epoch 268: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0626 - acc: 0.9774 - val_loss: 0.2414 - val_acc: 0.9594 - 1s/epoch - 4ms/step
# Epoch 269/1000
#
# Epoch 269: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0686 - acc: 0.9754 - val_loss: 0.2270 - val_acc: 0.9566 - 1s/epoch - 4ms/step
# Epoch 270/1000
#
# Epoch 270: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0660 - acc: 0.9760 - val_loss: 0.2182 - val_acc: 0.9566 - 1s/epoch - 4ms/step
# Epoch 271/1000
#
# Epoch 271: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0637 - acc: 0.9764 - val_loss: 0.2371 - val_acc: 0.9582 - 1s/epoch - 5ms/step
# Epoch 272/1000
#
# Epoch 272: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0712 - acc: 0.9745 - val_loss: 0.2439 - val_acc: 0.9590 - 1s/epoch - 4ms/step
# Epoch 273/1000
#
# Epoch 273: val_acc did not improve from 0.96347
# 308/308 - 1s - loss: 0.0622 - acc: 0.9754 - val_loss: 0.2442 - val_acc: 0.9586 - 1s/epoch - 4ms/step
# Epoch 274/1000
#
# Epoch 274: val_acc did not improve from 0.96347
# ...
#
# Epoch 353: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0842 - acc: 0.9682 - val_loss: 0.2376 - val_acc: 0.9318 - 1s/epoch - 5ms/step
# Epoch 354/1000
#
# Epoch 354: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0792 - acc: 0.9685 - val_loss: 0.2350 - val_acc: 0.9322 - 1s/epoch - 4ms/step
# Epoch 355/1000
#
# Epoch 355: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0802 - acc: 0.9677 - val_loss: 0.2403 - val_acc: 0.9338 - 1s/epoch - 5ms/step
# Epoch 356/1000
#
# Epoch 356: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0871 - acc: 0.9661 - val_loss: 0.2316 - val_acc: 0.9334 - 1s/epoch - 4ms/step
# Epoch 357/1000
#
# Epoch 357: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0874 - acc: 0.9664 - val_loss: 0.2187 - val_acc: 0.9399 - 1s/epoch - 4ms/step
# Epoch 358/1000
#
# Epoch 358: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0851 - acc: 0.9677 - val_loss: 0.2200 - val_acc: 0.9367 - 1s/epoch - 4ms/step
# Epoch 359/1000
#
# Epoch 359: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0840 - acc: 0.9684 - val_loss: 0.2335 - val_acc: 0.9359 - 1s/epoch - 5ms/step
# Epoch 360/1000
#
# Epoch 360: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0887 - acc: 0.9689 - val_loss: 0.2355 - val_acc: 0.9314 - 1s/epoch - 4ms/step
# Epoch 361/1000
#
# Epoch 361: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0834 - acc: 0.9706 - val_loss: 0.2324 - val_acc: 0.9326 - 1s/epoch - 4ms/step
# Epoch 362/1000
#
# Epoch 362: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0927 - acc: 0.9674 - val_loss: 0.2210 - val_acc: 0.9347 - 1s/epoch - 4ms/step
# Epoch 363/1000
#
# Epoch 363: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0808 - acc: 0.9688 - val_loss: 0.2352 - val_acc: 0.9363 - 1s/epoch - 4ms/step
# Epoch 364/1000
#
# Epoch 364: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0825 - acc: 0.9686 - val_loss: 0.2397 - val_acc: 0.9330 - 1s/epoch - 4ms/step
# Epoch 365/1000
#
# Epoch 365: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0875 - acc: 0.9684 - val_loss: 0.2594 - val_acc: 0.9338 - 1s/epoch - 5ms/step
# Epoch 366/1000
#
# Epoch 366: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0863 - acc: 0.9673 - val_loss: 0.2511 - val_acc: 0.9338 - 1s/epoch - 4ms/step
# Epoch 367/1000
#
# Epoch 367: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0859 - acc: 0.9698 - val_loss: 0.2395 - val_acc: 0.9363 - 1s/epoch - 4ms/step
# Epoch 368/1000
#
# Epoch 368: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0818 - acc: 0.9689 - val_loss: 0.2375 - val_acc: 0.9338 - 1s/epoch - 4ms/step
# Epoch 369/1000
#
# Epoch 369: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0872 - acc: 0.9675 - val_loss: 0.2432 - val_acc: 0.9355 - 1s/epoch - 4ms/step
# Epoch 370/1000
#
# Epoch 370: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0944 - acc: 0.9684 - val_loss: 0.2294 - val_acc: 0.9355 - 1s/epoch - 5ms/step
# Epoch 371/1000
#
# Epoch 371: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0860 - acc: 0.9662 - val_loss: 0.2397 - val_acc: 0.9387 - 1s/epoch - 4ms/step
# Epoch 372/1000
#
# Epoch 372: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0827 - acc: 0.9689 - val_loss: 0.2419 - val_acc: 0.9343 - 1s/epoch - 5ms/step
# Epoch 373/1000
#
# Epoch 373: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0828 - acc: 0.9679 - val_loss: 0.2443 - val_acc: 0.9359 - 1s/epoch - 4ms/step
# Epoch 374/1000
#
# Epoch 374: val_acc did not improve from 0.94075
# 308/308 - 2s - loss: 0.0807 - acc: 0.9696 - val_loss: 0.2490 - val_acc: 0.9359 - 2s/epoch - 5ms/step
# Epoch 375/1000
#
# Epoch 375: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0852 - acc: 0.9678 - val_loss: 0.2389 - val_acc: 0.9338 - 1s/epoch - 4ms/step
# Epoch 376/1000
#
# Epoch 376: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0782 - acc: 0.9681 - val_loss: 0.2706 - val_acc: 0.9326 - 1s/epoch - 4ms/step
# Epoch 377/1000
#
# Epoch 377: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0870 - acc: 0.9638 - val_loss: 0.2478 - val_acc: 0.9347 - 1s/epoch - 4ms/step
# Epoch 378/1000
#
# Epoch 378: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0846 - acc: 0.9696 - val_loss: 0.2491 - val_acc: 0.9334 - 1s/epoch - 4ms/step
# Epoch 379/1000
#
# Epoch 379: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0789 - acc: 0.9692 - val_loss: 0.2612 - val_acc: 0.9318 - 1s/epoch - 4ms/step
# Epoch 380/1000
#
# Epoch 380: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0894 - acc: 0.9659 - val_loss: 0.2662 - val_acc: 0.9318 - 1s/epoch - 5ms/step
# Epoch 381/1000
#
# Epoch 381: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0794 - acc: 0.9702 - val_loss: 0.2629 - val_acc: 0.9326 - 1s/epoch - 5ms/step
# Epoch 382/1000
#
# Epoch 382: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0830 - acc: 0.9689 - val_loss: 0.2635 - val_acc: 0.9343 - 1s/epoch - 4ms/step
# Epoch 383/1000
#
# Epoch 383: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0893 - acc: 0.9657 - val_loss: 0.2311 - val_acc: 0.9334 - 1s/epoch - 5ms/step
# Epoch 384/1000
#
# Epoch 384: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0807 - acc: 0.9695 - val_loss: 0.2352 - val_acc: 0.9343 - 1s/epoch - 4ms/step
# Epoch 385/1000
#
# Epoch 385: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0881 - acc: 0.9694 - val_loss: 0.2351 - val_acc: 0.9330 - 1s/epoch - 5ms/step
# Epoch 386/1000
#
# Epoch 386: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0894 - acc: 0.9687 - val_loss: 0.2366 - val_acc: 0.9359 - 1s/epoch - 4ms/step
# Epoch 387/1000
#
# Epoch 387: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0788 - acc: 0.9674 - val_loss: 0.2337 - val_acc: 0.9347 - 1s/epoch - 4ms/step
# Epoch 388/1000
#
# Epoch 388: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0909 - acc: 0.9654 - val_loss: 0.2328 - val_acc: 0.9355 - 1s/epoch - 4ms/step
# Epoch 389/1000
#
# Epoch 389: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0882 - acc: 0.9666 - val_loss: 0.2330 - val_acc: 0.9351 - 1s/epoch - 4ms/step
# Epoch 390/1000
#
# Epoch 390: val_acc did not improve from 0.94075
# 308/308 - 2s - loss: 0.0819 - acc: 0.9677 - val_loss: 0.2326 - val_acc: 0.9306 - 2s/epoch - 5ms/step
# Epoch 391/1000
#
# Epoch 391: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0798 - acc: 0.9695 - val_loss: 0.2347 - val_acc: 0.9322 - 1s/epoch - 5ms/step
# Epoch 392/1000
#
# Epoch 392: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0764 - acc: 0.9709 - val_loss: 0.2470 - val_acc: 0.9326 - 1s/epoch - 4ms/step
# Epoch 393/1000
#
# Epoch 393: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0836 - acc: 0.9705 - val_loss: 0.2301 - val_acc: 0.9347 - 1s/epoch - 4ms/step
# Epoch 394/1000
#
# Epoch 394: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0840 - acc: 0.9675 - val_loss: 0.2343 - val_acc: 0.9310 - 1s/epoch - 4ms/step
# Epoch 395/1000
#
# Epoch 395: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0826 - acc: 0.9677 - val_loss: 0.2342 - val_acc: 0.9334 - 1s/epoch - 4ms/step
# Epoch 396/1000
#
# Epoch 396: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0812 - acc: 0.9684 - val_loss: 0.2397 - val_acc: 0.9359 - 1s/epoch - 5ms/step
# Epoch 397/1000
#
# Epoch 397: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0760 - acc: 0.9706 - val_loss: 0.2491 - val_acc: 0.9367 - 1s/epoch - 4ms/step
# Epoch 398/1000
#
# Epoch 398: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0815 - acc: 0.9686 - val_loss: 0.2497 - val_acc: 0.9318 - 1s/epoch - 4ms/step
# Epoch 399/1000
#
# Epoch 399: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0848 - acc: 0.9651 - val_loss: 0.2598 - val_acc: 0.9306 - 1s/epoch - 4ms/step
# Epoch 400/1000
#
# Epoch 400: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0880 - acc: 0.9697 - val_loss: 0.2372 - val_acc: 0.9338 - 1s/epoch - 4ms/step
# Epoch 401/1000
#
# Epoch 401: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0787 - acc: 0.9716 - val_loss: 0.2598 - val_acc: 0.9330 - 1s/epoch - 4ms/step
# Epoch 402/1000
#
# Epoch 402: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0836 - acc: 0.9695 - val_loss: 0.2564 - val_acc: 0.9343 - 1s/epoch - 4ms/step
# Epoch 403/1000
#
# Epoch 403: val_acc did not improve from 0.94075
# 308/308 - 2s - loss: 0.0786 - acc: 0.9699 - val_loss: 0.2406 - val_acc: 0.9326 - 2s/epoch - 5ms/step
# Epoch 404/1000
#
# Epoch 404: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0819 - acc: 0.9675 - val_loss: 0.2551 - val_acc: 0.9347 - 1s/epoch - 5ms/step
# Epoch 405/1000
#
# Epoch 405: val_acc did not improve from 0.94075
# 308/308 - 2s - loss: 0.0766 - acc: 0.9707 - val_loss: 0.2387 - val_acc: 0.9343 - 2s/epoch - 7ms/step
# Epoch 406/1000
#
# Epoch 406: val_acc did not improve from 0.94075
# 308/308 - 2s - loss: 0.0839 - acc: 0.9720 - val_loss: 0.2462 - val_acc: 0.9330 - 2s/epoch - 6ms/step
# Epoch 407/1000
#
# Epoch 407: val_acc did not improve from 0.94075
# 308/308 - 2s - loss: 0.0748 - acc: 0.9723 - val_loss: 0.2384 - val_acc: 0.9347 - 2s/epoch - 5ms/step
# Epoch 408/1000
#
# Epoch 408: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0919 - acc: 0.9675 - val_loss: 0.2412 - val_acc: 0.9302 - 1s/epoch - 5ms/step
# Epoch 409/1000
#
# Epoch 409: val_acc did not improve from 0.94075
# 308/308 - 2s - loss: 0.0784 - acc: 0.9702 - val_loss: 0.2544 - val_acc: 0.9334 - 2s/epoch - 5ms/step
# Epoch 410/1000
#
# Epoch 410: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0748 - acc: 0.9701 - val_loss: 0.2581 - val_acc: 0.9326 - 1s/epoch - 4ms/step
# Epoch 411/1000
#
# Epoch 411: val_acc did not improve from 0.94075
# 308/308 - 2s - loss: 0.0852 - acc: 0.9697 - val_loss: 0.2666 - val_acc: 0.9351 - 2s/epoch - 5ms/step
# Epoch 412/1000
#
# Epoch 412: val_acc did not improve from 0.94075
# 308/308 - 2s - loss: 0.0809 - acc: 0.9683 - val_loss: 0.2439 - val_acc: 0.9343 - 2s/epoch - 5ms/step
# Epoch 413/1000
#
# Epoch 413: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0849 - acc: 0.9674 - val_loss: 0.2367 - val_acc: 0.9355 - 1s/epoch - 5ms/step
# Epoch 414/1000
#
# Epoch 414: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0833 - acc: 0.9682 - val_loss: 0.2453 - val_acc: 0.9379 - 1s/epoch - 4ms/step
# Epoch 415/1000
#
# Epoch 415: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0829 - acc: 0.9689 - val_loss: 0.2323 - val_acc: 0.9310 - 1s/epoch - 5ms/step
# Epoch 416/1000
#
# Epoch 416: val_acc did not improve from 0.94075
# 308/308 - 1s - loss: 0.0843 - acc: 0.9719 - val_loss: 0.2372 - val_acc: 0.9351 - 1s/epoch - 5ms/step
# Epoch 417/1000
#
# Epoch 417: val_acc did not improve from 0.94075
# 308/308 - 2s - loss: 0.0777 - acc: 0.9716 - val_loss: 0.2253 - val_acc: 0.9343 - 2s/epoch - 6ms/step
# Epoch 418/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 30
#      27 cpu_start = time.process_time()
#      28 wt_start = time.time()
# ---> 30 history = model.fit(train_fold, epochs=epochs, validation_data=val_fold, callbacks=myCallbacks(log_path), verbose=2)
#      32 wt_end = time.time()
#      33 cpu_end = time.process_time()
#
# File c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\farra\anaconda3\envs\tf_win_gpu\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
# Load Best Model
LAG = 64

test_dir = f"datasets/tf_batch/bispectrum_pyramid_relative/segment_{SEGMENT_TIME} seconds/test_{LAG}"
test_ds = tf.data.Dataset.load(test_dir)
model_dir = [f"train_logs/logs1/BISPECTRUM_PYRAMID_FILTER_RELATIVE_512_256_Adam/{i}/{LAG}/best_model.h5" for i in range(1,6)]

# %%
flattened_test = test_ds.unbatch()
test_data = list(flattened_test.as_numpy_iterator())

# %%
test_data_value = np.array([test_data[i][0] for i in range(len(test_data))])
test_data_label = np.array([test_data[i][1] for i in range(len(test_data))])

# %%
test_data_value.reshape(test_data_value.shape[0], -1).shape
# Out:
# (3080, 240)

# %%
results = []

for i, model_path in enumerate(model_dir):
    model = keras.models.load_model(model_path)
    loss, acc = model.evaluate(test_ds)
    print(loss, acc)
    pred = model.predict(test_data_value.reshape(test_data_value.shape[0], -1))
    results.append(pred)
# Out:
# 97/97 [==============================] - 1s 4ms/step - loss: 0.3324 - acc: 0.8896
# 0.3323672413825989 0.8896104097366333
# 97/97 [==============================] - 0s 2ms/step
# 97/97 [==============================] - 0s 3ms/step - loss: 0.4966 - acc: 0.8886
# 0.49660032987594604 0.8886363506317139
# 97/97 [==============================] - 0s 2ms/step
# 97/97 [==============================] - 1s 4ms/step - loss: 0.4443 - acc: 0.9000
# 0.44430723786354065 0.8999999761581421
# 97/97 [==============================] - 0s 2ms/step
# 97/97 [==============================] - 0s 4ms/step - loss: 0.6288 - acc: 0.8873
# 0.6287662982940674 0.8873376846313477
# 97/97 [==============================] - 0s 2ms/step
# 97/97 [==============================] - 1s 4ms/step - loss: 0.3741 - acc: 0.8916
# 0.37407365441322327 0.8915584683418274
# 97/97 [==============================] - 0s 2ms/step

# %%
from sklearn import metrics

for i, res in enumerate(results, 1):
    pred = np.round(res.reshape(res.shape[0])).astype(bool)
    confusion_matrix = metrics.confusion_matrix(test_data_label.astype(bool), pred)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['normal', 'autism'])
    cm_display.plot()
    plt.title(f"Result: Bispectrum FFT Relative ANN (512,256)(Adam) lag 128 for model in fold {i}")
    plt.show()

# %%
for i, res in enumerate(results, 1):
    pred = np.round(res.reshape(res.shape[0])).astype(bool)
    test_data_label = test_data_label.astype(bool)  

    print(f"Result: BISPECTRUM FILTER PYRAMID ANN (512,256)(Adam) lag 128 for model in fold {i}")

    TP = np.sum((test_data_label == True) & (pred == True))
    FP = np.sum((test_data_label == False) & (pred == True))
    TN = np.sum((test_data_label == False) & (pred == False))
    FN = np.sum((test_data_label == True) & (pred == False))  

    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"Accuracy: {accuracy}")
    print(f"F1-score: {f1_score}")
    print("\n")
# Out:
# Result: BISPECTRUM FILTER PYRAMID ANN (512,256)(Adam) lag 128 for model in fold 1
# Precision: 0.9123543123543123
# Recall: 0.9279279279279279
# Accuracy: 0.8896103896103896
# F1-score: 0.920075223319229
#
#
# Result: BISPECTRUM FILTER PYRAMID ANN (512,256)(Adam) lag 128 for model in fold 2
# Precision: 0.9072878228782287
# Recall: 0.93266951161688
# Accuracy: 0.8886363636363637
# F1-score: 0.9198036006546645
#
#
# Result: BISPECTRUM FILTER PYRAMID ANN (512,256)(Adam) lag 128 for model in fold 3
# Precision: 0.9072817729534147
# Recall: 0.9511616880037933
# Accuracy: 0.9
# F1-score: 0.9287037037037037
#
#
# Result: BISPECTRUM FILTER PYRAMID ANN (512,256)(Adam) lag 128 for model in fold 4
# Precision: 0.8975631768953068
# Recall: 0.9431009957325747
# Accuracy: 0.8873376623376623
# F1-score: 0.9197687861271676
#
#
# Result: BISPECTRUM FILTER PYRAMID ANN (512,256)(Adam) lag 128 for model in fold 5
# Precision: 0.9129827826896231
# Recall: 0.930298719772404
# Accuracy: 0.8915584415584416
# F1-score: 0.9215594175669328

# %%
test_model = keras.models.Sequential()

test_model.add(layers.Input(shape=(240,)))

test_model.add(layers.Dense(512, activation="relu"))

test_model.add(layers.Dropout(0.5))

test_model.add(layers.Dense(256, activation="relu"))

test_model.add(layers.Dropout(0.5))

test_model.add(layers.Dense(1, activation="sigmoid"))

keras.utils.plot_model(test_model, show_layer_activations=True, show_shapes=True, show_layer_names=False)

# %%
# for log_dir in log_dirs:
#     recap = pd.DataFrame(index=lags, columns=folds)
#     training_time = pd.DataFrame(index=lags, columns=time_measured)
#     for fold in range(1,3):
#         for lag in lags:
#             if fold == 2:
#                 train_dir, test_dir = test_dir, train_dir
            
#             train_temp_dir = train_dir + '_' + str(lag)
#             test_temp_dir = test_dir + '_' + str(lag)

#             train = get_batch(train_temp_dir)
#             test_ds = get_batch(test_temp_dir)

#             train_size = int(len(list(train.as_numpy_iterator()))*0.8)
#             train_ds = train.take(train_size)
#             val_ds = train.skip(train_size)

#             log_path = os.path.join(log_dir, str(fold), str(lag))

#             model = create_model()
#             model.summary()

#             model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['acc'])

#             cpu_start = time.process_time()
#             wt_start = time.time()

#             history = model.fit(train_ds, epochs=epochs, validation_data=(val_ds), callbacks = myCallbacks(log_path))

#             wt_end = time.time()
#             cpu_end = time.process_time()
#             wall_time = wt_end - wt_start
#             cpu_time = cpu_end - cpu_start
#             training_time.loc[lag, 'CPU_Time'+ '_' + str(fold)] = cpu_time
#             training_time.loc[lag, 'Wall_Time'+ '_' + str(fold)] = wall_time

#             results = model.evaluate(test_ds, callbacks = myCallbacks(log_path))

#             recap.loc[lag, 'train'+ '_' + str(fold)] = history.history['acc']
#             recap.loc[lag, 'test'+ '_' + str(fold)] = results[1]
#             recap.loc[lag, 'epoch'+ '_' + str(fold)] = len(history.history['acc'])
#     log_dir = os.path.join(log_dir,'Recap')
#     if not os.path.exists(log_dir):
#         os.makedirs(log_dir)
#     recap.to_csv(os.path.join(log_dir,'recap.csv'))
#     training_time.to_csv(os.path.join(log_dir,'Training_time.csv'))

# %%
# %load_ext tensorboard

# %%
! tensorboard --logdir c:/Users/farra/Documents/Pribadi/EEG/EEG-Autism-Classification --port=8000
# Out:
# ^C

# %%
# %tensorboard --logdir logs --port=8000

# %%
! cd
# Out:
# c:\Users\farra\Documents\Pribadi\EEG\EEG-Autism-Classification
