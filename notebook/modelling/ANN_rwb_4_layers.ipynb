# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import preprocessing, model_selection
import csv
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import time
import json
import random

# %% [markdown]
# ### Data Preparation

# %%
def get_dataset(directory, lag, excluded_name=[]):
    data = pd.DataFrame(columns=['data', 'label'])
    for foldername in os.listdir(directory):        
        folder = os.path.join(directory, foldername)
        # print(folder)
        if str(lag) in folder:
            # print(os.listdir(folder))
            for name in os.listdir(folder):
                if name in excluded_name:
                    # print(name)
                    continue
                filename = os.path.join(folder, name)
                # print(filename)
                for files in os.listdir(filename):
                    rel_path = os.path.join(filename, files)
                    # print(rel_path)
                    temp_label = folder
                    if "autism" in temp_label:
                        label = 'autism'
                    else:
                        label = 'normal'

                    temp_data = pd.DataFrame(columns=['data', 'label'], index=[0])

                    rwb = np.load(rel_path)
                    rwb.astype(np.float64).reshape(-1,1)
                                    
                    temp_data.loc[0, "data"] = rwb
                    temp_data['label'] = label
                    data = pd.concat([data, temp_data], ignore_index=True)
    label_map = {"autism": 1, "normal": 0}
    data['label_map'] = data['label'].map(label_map)      
    return data

# %%
def remove_missing_value(data):
    series_list = np.vstack(data["data"].values)
    labels_list = data["label_map"].values    
    missing_indices = np.where(np.isnan(series_list).any(axis=1))[0]

    clean_data = data.drop(index=data.index[missing_indices])
    return clean_data

# %%
def save_dataset(data, des_path):
    if not os.path.exists(des_path):
        os.makedirs(des_path)
    data.save(des_path)

# %%
def get_train_test(data, train_split: float):
    train_x, test_x, train_y, test_y = model_selection.train_test_split(
        data['data'],
        data[['label', 'label_map']],
        train_size=train_split,
        stratify=data['label_map']
    )

    train_df = pd.DataFrame(columns=['data', 'label', 'label_map'])
    test_df = pd.DataFrame(columns=['data', 'label', 'label_map'])

    train_df["data"] = train_x
    train_df[['label', 'label_map']] = train_y

    test_df["data"] = test_x
    test_df[['label', 'label_map']] = test_y

    return train_df, test_df

# %%
def get_batch(data):
    # loading extracted feature & label
    # x = get_dataset(path, lag, excluded_name)

    # scaler = preprocessing.MinMaxScaler()

    series_list = np.vstack(data["data"].values)

    # series_list = series_list.reshape(-1, 366, 1)

    labels_list = data["label_map"].values
        
    # y = keras.utils.to_categorical(y[0])
    dataset = tf.data.Dataset.from_tensor_slices((series_list,labels_list))
    dataset = dataset.shuffle(len(labels_list))

    # train_size = int(train_split * len(labels_list))  
    # test_size = len(labels_list) - train_size  

    # train_dataset = dataset.take(train_size)
    # test_dataset = dataset.skip(train_size)

    BATCH_SIZE = 32

    dataset = dataset.batch(BATCH_SIZE)

    return dataset

# %%
data_dir = "datasets/features/rwb_f_only/segment_1 seconds"

train_dir = "datasets/tf_batch/rwb_f_only/segment_1 seconds/train"
test_dir = "datasets/tf_batch/rwb_f_only/segment_1 seconds/test"

# %%
excluded = ["zyad"]
train_split = 0.8
LAG = [256]

for lag in LAG:
    data = get_dataset(data_dir, lag, excluded)
    print(data.shape)
    data = remove_missing_value(data)
    print(data.shape)
    train_data, test_data = get_train_test(data, train_split)
    print("train: ", train_data.shape)
    print("test: ", test_data.shape)
    train_batch = get_batch(train_data)
    test_batch = get_batch(test_data)
    tf.data.Dataset.save(train_batch, f"{train_dir}_{lag}")
    tf.data.Dataset.save(test_batch, f"{test_dir}_{lag}")
# Out:
# (15434, 3)
# (14821, 3)
# train:  (11856, 3)
# test:  (2965, 3)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Load the CSV file into a DataFrame
signal = np.load("datasets/features/rwb_f_only/segment_1 seconds/normal_256/amer/Amer_segment_1.csv_rwb.npy")

# Extract the signal values from the DataFrame

# Create a time axis for the signal
t = range(len(signal))
print(len(signal))
fig, ax = plt.subplots(figsize=(10, 5))
# Plot the signal
ax.plot(t, signal)
ax.set_xlabel('Time (samples)')
ax.set_ylabel('Signal amplitude')
ax.set_title('Signal plot')
plt.show()
# Out:
# 42

# %% [markdown]
# ### Model Definition

# %%
def create_model():
    model = keras.models.Sequential()

    model.add(layers.Input(shape=(42,)))
    model.add(layers.Reshape((42, 1)))
    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation="relu"))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(256, activation="relu"))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(512, activation="relu"))
    model.add(layers.Dense(1, activation="sigmoid"))

    return model

# %% [markdown]
# ### Define Callbacks

# %%
def myCallbacks(log_dir):
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
    early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='acc',
    patience=50,
    mode='max')
    model_path = os.path.join(log_dir,'best_model.h5')
    mc = tf.keras.callbacks.ModelCheckpoint(model_path, monitor='val_acc', mode='max', verbose=1, save_best_only=True)
    return [tensorboard_callback, early_stopping, mc]

# %% [markdown]
# ### Main Program

# %%
lags = [256]
# folds = ['train_1', 'test_1', 'epoch_1', 'train_2', 'test_2', 'epoch_2']
time_measured = ['Wall_Time_1', 'CPU_Time_1', 'Wall_Time_2', 'CPU_Time_2']
epochs = 2000
log_dirs = [f"train_logs/logs9/RWB_F_ONLY_ANN_512_256_512_Adam"]

# %%
for log_dir in log_dirs:
    recap = pd.DataFrame(index=lags, columns=range(1, 11))
    training_time = pd.DataFrame(index=lags, columns=[f'CPU_Time_{i}' for i in range(1, 6)] + [f'Wall_Time_{i}' for i in range(1, 11)])

    for lag in lags:
        train_temp_dir = train_dir + '_' + str(lag)
        train = tf.data.Dataset.load(train_temp_dir)
        flattened_train = train.unbatch()

        train_data = list(flattened_train.as_numpy_iterator())
        train_size = len(list(train_data))

        X = [train_data[i][0] for i in range(train_size)]  # features
        y = [train_data[i][1] for i in range(train_size)]  # labels

        skf = model_selection.StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

        for fold, (train_index, val_index) in enumerate(skf.split(X, y), 1):
            train_fold_data = ([X[i] for i in train_index], [y[i] for i in train_index])
            val_fold_data = ([X[i] for i in val_index], [y[i] for i in val_index])

            train_fold = tf.data.Dataset.from_tensor_slices(train_fold_data).batch(32)
            val_fold = tf.data.Dataset.from_tensor_slices(val_fold_data).batch(32)

            log_path = os.path.join(log_dir, str(fold), str(lag))

            model = create_model()
            model.summary()

            model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['acc'])

            cpu_start = time.process_time()
            wt_start = time.time()

            history = model.fit(train_fold, epochs=epochs, validation_data=val_fold, callbacks=myCallbacks(log_path))

            wt_end = time.time()
            cpu_end = time.process_time()
            wall_time = wt_end - wt_start
            cpu_time = cpu_end - cpu_start

            training_time.loc[lag, f'CPU_Time_{fold}'] = cpu_time
            training_time.loc[lag, f'Wall_Time_{fold}'] = wall_time

            recap.loc[lag, fold] = history.history['acc'][-1]


    # Evaluate on the test dataset after cross-validation
    test_temp_dir = test_dir + '_' + str(lag)
    test_ds = tf.data.Dataset.load(test_temp_dir)
    results = model.evaluate(test_ds, callbacks=myCallbacks(log_path))

    recap[f'test_{lag}'] = results[1]

    log_recap_dir = os.path.join(log_dir, 'Recap')
    if not os.path.exists(log_recap_dir):
        os.makedirs(log_recap_dir)

    recap.to_csv(os.path.join(log_recap_dir, 'recap.csv'))
    training_time.to_csv(os.path.join(log_recap_dir, 'Training_time.csv'))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 42, 1)             0
#
#  flatten (Flatten)           (None, 42)                0
#
#  dense (Dense)               (None, 512)               22016
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 285,441
# Trainable params: 285,441
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2000
# 330/334 [============================>.] - ETA: 0s - loss: 0.9651 - acc: 0.6199
# Epoch 1: val_acc improved from -inf to 0.69309, saving model to train_logs/logs9/RWB_F_ONLY_ANN_512_256_512_Adam\1\256\best_model.h5
# 334/334 [==============================] - 2s 4ms/step - loss: 0.9614 - acc: 0.6205 - val_loss: 0.6327 - val_acc: 0.6931
# Epoch 2/2000
# 328/334 [============================>.] - ETA: 0s - loss: 0.6387 - acc: 0.6742
# Epoch 2: val_acc improved from 0.69309 to 0.70152, saving model to train_logs/logs9/RWB_F_ONLY_ANN_512_256_512_Adam\1\256\best_model.h5
# 334/334 [==============================] - 1s 3ms/step - loss: 0.6382 - acc: 0.6746 - val_loss: 0.5945 - val_acc: 0.7015
# Epoch 3/2000
# 315/334 [===========================>..] - ETA: 0s - loss: 0.6163 - acc: 0.6873
# Epoch 3: val_acc did not improve from 0.70152
# 334/334 [==============================] - 1s 3ms/step - loss: 0.6155 - acc: 0.6873 - val_loss: 0.5950 - val_acc: 0.6973
# Epoch 4/2000
# 330/334 [============================>.] - ETA: 0s - loss: 0.6083 - acc: 0.6950
# Epoch 14: val_acc did not improve from 0.72007
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5804 - acc: 0.7123 - val_loss: 0.5735 - val_acc: 0.7142
# Epoch 15/2000
# 330/334 [============================>.] - ETA: 0s - loss: 0.5753 - acc: 0.7165
# Epoch 15: val_acc did not improve from 0.72007
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5753 - acc: 0.7165 - val_loss: 0.5726 - val_acc: 0.7142
# Epoch 16/2000
# 322/334 [===========================>..] - ETA: 0s - loss: 0.5737 - acc: 0.7159
# Epoch 16: val_acc did not improve from 0.72007
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5736 - acc: 0.7157 - val_loss: 0.5684 - val_acc: 0.7201
# Epoch 17/2000
# 319/334 [===========================>..] - ETA: 0s - loss: 0.5698 - acc: 0.7167
# Epoch 17: val_acc did not improve from 0.72007
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5697 - acc: 0.7164 - val_loss: 0.5673 - val_acc: 0.7159
# Epoch 18/2000
# 312/334 [===========================>..] - ETA: 0s - loss: 0.5679 - acc: 0.7173
# Epoch 18: val_acc did not improve from 0.72007
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5693 - acc: 0.7151 - val_loss: 0.5701 - val_acc: 0.7192
# Epoch 19/2000
# 321/334 [===========================>..] - ETA: 0s - loss: 0.5652 - acc: 0.7232
# Epoch 19: val_acc improved from 0.72007 to 0.72091, saving model to train_logs/logs9/RWB_F_ONLY_ANN_512_256_512_Adam\1\256\best_model.h5
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5648 - acc: 0.7232 - val_loss: 0.5642 - val_acc: 0.7209
# Epoch 20/2000
# 327/334 [============================>.] - ETA: 0s - loss: 0.5628 - acc: 0.7211
# Epoch 20: val_acc did not improve from 0.72091
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5622 - acc: 0.7218 - val_loss: 0.5660 - val_acc: 0.7209
# Epoch 21/2000
# 315/334 [===========================>..] - ETA: 0s - loss: 0.5564 - acc: 0.7273
# Epoch 21: val_acc improved from 0.72091 to 0.72766, saving model to train_logs/logs9/RWB_F_ONLY_ANN_512_256_512_Adam\1\256\best_model.h5
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5563 - acc: 0.7270 - val_loss: 0.5548 - val_acc: 0.7277
# Epoch 22/2000
# 327/334 [============================>.] - ETA: 0s - loss: 0.5546 - acc: 0.7259
# Epoch 22: val_acc did not improve from 0.72766
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5543 - acc: 0.7258 - val_loss: 0.5542 - val_acc: 0.7192
# Epoch 23/2000
# 319/334 [===========================>..] - ETA: 0s - loss: 0.5541 - acc: 0.7293
# Epoch 23: val_acc did not improve from 0.72766
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5535 - acc: 0.7295 - val_loss: 0.5570 - val_acc: 0.7218
# Epoch 24/2000
# 323/334 [============================>.] - ETA: 0s - loss: 0.5527 - acc: 0.7266
# Epoch 24: val_acc did not improve from 0.72766
# 334/334 [==============================] - 2s 5ms/step - loss: 0.3831 - acc: 0.8203 - val_loss: 0.6325 - val_acc: 0.7823
# Epoch 562/2000
# 326/334 [============================>.] - ETA: 0s - loss: 0.4428 - acc: 0.8147
# Epoch 562: val_acc did not improve from 0.80169
# 334/334 [==============================] - 2s 5ms/step - loss: 0.4417 - acc: 0.8145 - val_loss: 0.6336 - val_acc: 0.7713
# Epoch 563/2000
# 333/334 [============================>.] - ETA: 0s - loss: 0.3933 - acc: 0.8170
# Epoch 563: val_acc did not improve from 0.80169
# 334/334 [==============================] - 2s 5ms/step - loss: 0.3936 - acc: 0.8166 - val_loss: 0.6132 - val_acc: 0.7755
# Epoch 564/2000
# 326/334 [============================>.] - ETA: 0s - loss: 0.3798 - acc: 0.8214
# Epoch 564: val_acc did not improve from 0.80169
# 334/334 [==============================] - 2s 5ms/step - loss: 0.3798 - acc: 0.8212 - val_loss: 0.5988 - val_acc: 0.7857
# 93/93 [==============================] - 0s 2ms/step - loss: 0.5804 - acc: 0.7845

# %%
# Load Best Model
LAG = 256

test_dir = f"datasets/tf_batch/rwb_f_only/segment_1 seconds/test_{LAG}"
test_ds = tf.data.Dataset.load(test_dir)
model_dir = [f"train_logs/logs9/RWB_F_ONLY_ANN_512_256_512_Adam/{i}/{LAG}/best_model.h5" for i in range(1,11)]

# %%
flattened_test = test_ds.unbatch()
test_data = list(flattened_test.as_numpy_iterator())

# %%
test_data_value = np.array([test_data[i][0] for i in range(len(test_data))])
test_data_label = np.array([test_data[i][1] for i in range(len(test_data))])

# %%
test_data_value.reshape(test_data_value.shape[0], -1).shape
# Out:
# (2965, 42)

# %%
results = []

for i, model_path in enumerate(model_dir):
    model = keras.models.load_model(model_path)
    loss, acc = model.evaluate(test_ds)
    print(loss, acc)
    pred = model.predict(test_data_value.reshape(test_data_value.shape[0], -1))
    results.append(pred)
# Out:
# 93/93 [==============================] - 0s 1ms/step - loss: 0.5985 - acc: 0.7825
# 0.5984575748443604 0.7824620604515076
# 93/93 [==============================] - 0s 2ms/step
# 93/93 [==============================] - 0s 1ms/step - loss: 1.0839 - acc: 0.7909
# 1.0838677883148193 0.7908937335014343
# 93/93 [==============================] - 0s 2ms/step
# 93/93 [==============================] - 0s 1ms/step - loss: 0.5887 - acc: 0.8007
# 0.5886527895927429 0.800674557685852
# 93/93 [==============================] - 0s 2ms/step
# 93/93 [==============================] - 0s 2ms/step - loss: 0.5342 - acc: 0.7794
# 0.5342081189155579 0.779426634311676
# 93/93 [==============================] - 0s 2ms/step
# 93/93 [==============================] - 0s 1ms/step - loss: 0.5692 - acc: 0.7946
# 0.5691975951194763 0.794603705406189
# 93/93 [==============================] - 0s 1ms/step
# 93/93 [==============================] - 0s 1ms/step - loss: 0.6740 - acc: 0.7906
# 0.674004077911377 0.7905564904212952
# 93/93 [==============================] - 0s 1ms/step
# 93/93 [==============================] - 0s 1ms/step - loss: 0.6057 - acc: 0.7912
# 0.6056756377220154 0.7912310361862183
# 93/93 [==============================] - 0s 2ms/step
# 93/93 [==============================] - 0s 1ms/step - loss: 0.6596 - acc: 0.7872
# 0.6596097350120544 0.7871838212013245
# 93/93 [==============================] - 0s 2ms/step
# 93/93 [==============================] - 0s 2ms/step - loss: 0.6941 - acc: 0.7862
# 0.6940689086914062 0.7861720323562622
# 93/93 [==============================] - 0s 1ms/step
# 93/93 [==============================] - 0s 1ms/step - loss: 0.5803 - acc: 0.7885
# 0.5802735090255737 0.7885329127311707
# 93/93 [==============================] - 0s 2ms/step

# %%
from sklearn import metrics

for i, res in enumerate(results, 1):
    pred = np.round(res.reshape(res.shape[0])).astype(bool)
    confusion_matrix = metrics.confusion_matrix(test_data_label.astype(bool), pred)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['normal', 'autism'])
    cm_display.plot()
    plt.title(f"Result: RWB F ch. Only ANN (128,64,32,16,8)(Adam) lag 256 for model in fold {i}")
    plt.show()

# %%
precision_list = []
recall_list = []
accuracy_list = []
f1_score_list = []

for i, res in enumerate(results, 1):
    pred = np.round(res.reshape(res.shape[0])).astype(bool)
    test_data_label = test_data_label.astype(bool)  

    print(f"Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold {i}")

    TP = np.sum((test_data_label == True) & (pred == True))
    FP = np.sum((test_data_label == False) & (pred == True))
    TN = np.sum((test_data_label == False) & (pred == False))
    FN = np.sum((test_data_label == True) & (pred == False))  

    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    accuracy = (TP + TN) / (TP + TN + FP + FN)
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    precision_list.append(precision)
    recall_list.append(recall)
    accuracy_list.append(accuracy)
    f1_score_list.append(f1_score)
    
    # print(f"Precision: {precision}")
    # print(f"Recall: {recall}")
    # print(f"Accuracy: {accuracy}")
    # print(f"F1-score: {f1_score}")
    # print("\n")
print(f"Precision: {max(precision_list)}")
print(f"Recall: {max(recall_list)}")
print(f"Accuracy: {max(accuracy_list)}")
print(f"F1-score: {max(f1_score_list)}")
print("\n")
# Out:
# Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold 1
# Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold 2
# Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold 3
# Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold 4
# Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold 5
# Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold 6
# Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold 7
# Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold 8
# Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold 9
# Result: RWB ANN (128,64,32,16)(Adam) lag 256 for model in fold 10
# Precision: 0.7875203915171288
# Recall: 0.9770114942528736
# Accuracy: 0.8006745362563238
# F1-score: 0.8672804850662476
